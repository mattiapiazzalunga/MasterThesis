# %% [markdown]
# # Master Thesis - Mattia Piazzalunga
# In this notebook, the generation of the English dataset is carried out thanks to the data collected by Patrick Martinchek https://medium.com/newco/what-i-discovered-about-trump-and-clinton-from-analyzing-4-million-facebook-posts-922a4381fd2f

# %% [markdown]
# *Title*: Bridging a GAP: Text Style Transfer from Journalistic to Conversational for enhanced social media dissemination of news
#
# *Supervisor*: Gabriella Pasi <br>
# *Author*: Mattia Piazzalunga
#
# *University*: Bicocca University of Milan <br>
# *Department*: Informatics, Systems and Communication <br>
# *Course*: Computer Science <br>
# *Academic year*: 2023/2024
#
# *Info*: This notebook was run locally. Download the whole repository before running.
#
# *For suggestions or questions*: mattiapiazzalunga@outlook.com

# %% [markdown]
# ## Inizializzazion

# %% [markdown]
# ### Dowloading libraires

# %%
# !pip install requests lxml newspaper3k torch ipywidgets sentence-transformers
# Out:
# Requirement already satisfied: requests in /opt/conda/lib/python3.10/site-packages (2.32.3)
# Requirement already satisfied: lxml in /opt/conda/lib/python3.10/site-packages (5.3.0)
# Collecting newspaper3k
#   Downloading newspaper3k-0.2.8-py3-none-any.whl.metadata (11 kB)
# Requirement already satisfied: torch in /opt/conda/lib/python3.10/site-packages (2.4.0)
# Requirement already satisfied: ipywidgets in /opt/conda/lib/python3.10/site-packages (7.7.1)
# Collecting sentence-transformers
#   Downloading sentence_transformers-3.1.1-py3-none-any.whl.metadata (10 kB)
# Requirement already satisfied: charset-normalizer<4,>=2 in /opt/conda/lib/python3.10/site-packages (from requests) (3.3.2)
# Requirement already satisfied: idna<4,>=2.5 in /opt/conda/lib/python3.10/site-packages (from requests) (3.7)
# Requirement already satisfied: urllib3<3,>=1.21.1 in /opt/conda/lib/python3.10/site-packages (from requests) (1.26.18)
# Requirement already satisfied: certifi>=2017.4.17 in /opt/conda/lib/python3.10/site-packages (from requests) (2024.8.30)
# Requirement already satisfied: beautifulsoup4>=4.4.1 in /opt/conda/lib/python3.10/site-packages (from newspaper3k) (4.12.3)
# Requirement already satisfied: Pillow>=3.3.0 in /opt/conda/lib/python3.10/site-packages (from newspaper3k) (10.3.0)
# Requirement already satisfied: PyYAML>=3.11 in /opt/conda/lib/python3.10/site-packages (from newspaper3k) (6.0.2)
# Collecting cssselect>=0.9.2 (from newspaper3k)
#   Downloading cssselect-1.2.0-py2.py3-none-any.whl.metadata (2.2 kB)
# Requirement already satisfied: nltk>=3.2.1 in /opt/conda/lib/python3.10/site-packages (from newspaper3k) (3.2.4)
# Collecting feedparser>=5.2.1 (from newspaper3k)
#   Downloading feedparser-6.0.11-py3-none-any.whl.metadata (2.4 kB)
# Collecting tldextract>=2.0.1 (from newspaper3k)
#   Downloading tldextract-5.1.2-py3-none-any.whl.metadata (11 kB)
# Collecting feedfinder2>=0.0.4 (from newspaper3k)
#   Downloading feedfinder2-0.0.4.tar.gz (3.3 kB)
#   Preparing metadata (setup.py) ... done
# Collecting jieba3k>=0.35.1 (from newspaper3k)
#   Downloading jieba3k-0.35.1.zip (7.4 MB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 7.4/7.4 MB 64.8 MB/s eta 0:00:0000:0100:01
#   Preparing metadata (setup.py) ... done
# Requirement already satisfied: python-dateutil>=2.5.3 in /opt/conda/lib/python3.10/site-packages (from newspaper3k) (2.9.0.post0)
# Collecting tinysegmenter==0.3 (from newspaper3k)
#   Downloading tinysegmenter-0.3.tar.gz (16 kB)
#   Preparing metadata (setup.py) ... done
# Requirement already satisfied: filelock in /opt/conda/lib/python3.10/site-packages (from torch) (3.15.1)
# Requirement already satisfied: typing-extensions>=4.8.0 in /opt/conda/lib/python3.10/site-packages (from torch) (4.12.2)
# Requirement already satisfied: sympy in /opt/conda/lib/python3.10/site-packages (from torch) (1.13.3)
# Requirement already satisfied: networkx in /opt/conda/lib/python3.10/site-packages (from torch) (3.3)
# Requirement already satisfied: jinja2 in /opt/conda/lib/python3.10/site-packages (from torch) (3.1.4)
# Requirement already satisfied: fsspec in /opt/conda/lib/python3.10/site-packages (from torch) (2024.6.1)
# Requirement already satisfied: ipykernel>=4.5.1 in /opt/conda/lib/python3.10/site-packages (from ipywidgets) (6.29.4)
# Requirement already satisfied: ipython-genutils~=0.2.0 in /opt/conda/lib/python3.10/site-packages (from ipywidgets) (0.2.0)
# Requirement already satisfied: traitlets>=4.3.1 in /opt/conda/lib/python3.10/site-packages (from ipywidgets) (5.14.3)
# Requirement already satisfied: widgetsnbextension~=3.6.0 in /opt/conda/lib/python3.10/site-packages (from ipywidgets) (3.6.9)
# Requirement already satisfied: ipython>=4.0.0 in /opt/conda/lib/python3.10/site-packages (from ipywidgets) (8.21.0)
# Requirement already satisfied: jupyterlab-widgets>=1.0.0 in /opt/conda/lib/python3.10/site-packages (from ipywidgets) (3.0.11)
# Requirement already satisfied: transformers<5.0.0,>=4.38.0 in /opt/conda/lib/python3.10/site-packages (from sentence-transformers) (4.45.1)
# Requirement already satisfied: tqdm in /opt/conda/lib/python3.10/site-packages (from sentence-transformers) (4.66.4)
# Requirement already satisfied: scikit-learn in /opt/conda/lib/python3.10/site-packages (from sentence-transformers) (1.2.2)
# Requirement already satisfied: scipy in /opt/conda/lib/python3.10/site-packages (from sentence-transformers) (1.14.1)
# Requirement already satisfied: huggingface-hub>=0.19.3 in /opt/conda/lib/python3.10/site-packages (from sentence-transformers) (0.25.1)
# Requirement already satisfied: soupsieve>1.2 in /opt/conda/lib/python3.10/site-packages (from beautifulsoup4>=4.4.1->newspaper3k) (2.5)
# Requirement already satisfied: six in /opt/conda/lib/python3.10/site-packages (from feedfinder2>=0.0.4->newspaper3k) (1.16.0)
# Collecting sgmllib3k (from feedparser>=5.2.1->newspaper3k)
#   Downloading sgmllib3k-1.0.0.tar.gz (5.8 kB)
#   Preparing metadata (setup.py) ... done
# Requirement already satisfied: packaging>=20.9 in /opt/conda/lib/python3.10/site-packages (from huggingface-hub>=0.19.3->sentence-transformers) (21.3)
# Requirement already satisfied: comm>=0.1.1 in /opt/conda/lib/python3.10/site-packages (from ipykernel>=4.5.1->ipywidgets) (0.2.2)
# Requirement already satisfied: debugpy>=1.6.5 in /opt/conda/lib/python3.10/site-packages (from ipykernel>=4.5.1->ipywidgets) (1.8.1)
# Requirement already satisfied: jupyter-client>=6.1.12 in /opt/conda/lib/python3.10/site-packages (from ipykernel>=4.5.1->ipywidgets) (7.4.9)
# Requirement already satisfied: jupyter-core!=5.0.*,>=4.12 in /opt/conda/lib/python3.10/site-packages (from ipykernel>=4.5.1->ipywidgets) (5.7.2)
# Requirement already satisfied: matplotlib-inline>=0.1 in /opt/conda/lib/python3.10/site-packages (from ipykernel>=4.5.1->ipywidgets) (0.1.7)
# Requirement already satisfied: nest-asyncio in /opt/conda/lib/python3.10/site-packages (from ipykernel>=4.5.1->ipywidgets) (1.6.0)
# Requirement already satisfied: psutil in /opt/conda/lib/python3.10/site-packages (from ipykernel>=4.5.1->ipywidgets) (5.9.3)
# Requirement already satisfied: pyzmq>=24 in /opt/conda/lib/python3.10/site-packages (from ipykernel>=4.5.1->ipywidgets) (26.0.3)
# Requirement already satisfied: tornado>=6.1 in /opt/conda/lib/python3.10/site-packages (from ipykernel>=4.5.1->ipywidgets) (6.4.1)
# Requirement already satisfied: decorator in /opt/conda/lib/python3.10/site-packages (from ipython>=4.0.0->ipywidgets) (5.1.1)
# Requirement already satisfied: jedi>=0.16 in /opt/conda/lib/python3.10/site-packages (from ipython>=4.0.0->ipywidgets) (0.19.1)
# Requirement already satisfied: prompt-toolkit<3.1.0,>=3.0.41 in /opt/conda/lib/python3.10/site-packages (from ipython>=4.0.0->ipywidgets) (3.0.47)
# Requirement already satisfied: pygments>=2.4.0 in /opt/conda/lib/python3.10/site-packages (from ipython>=4.0.0->ipywidgets) (2.18.0)
# Requirement already satisfied: stack-data in /opt/conda/lib/python3.10/site-packages (from ipython>=4.0.0->ipywidgets) (0.6.2)
# Requirement already satisfied: exceptiongroup in /opt/conda/lib/python3.10/site-packages (from ipython>=4.0.0->ipywidgets) (1.2.0)
# Requirement already satisfied: pexpect>4.3 in /opt/conda/lib/python3.10/site-packages (from ipython>=4.0.0->ipywidgets) (4.9.0)
# Collecting requests-file>=1.4 (from tldextract>=2.0.1->newspaper3k)
#   Downloading requests_file-2.1.0-py2.py3-none-any.whl.metadata (1.7 kB)
# Requirement already satisfied: numpy>=1.17 in /opt/conda/lib/python3.10/site-packages (from transformers<5.0.0,>=4.38.0->sentence-transformers) (1.26.4)
# Requirement already satisfied: regex!=2019.12.17 in /opt/conda/lib/python3.10/site-packages (from transformers<5.0.0,>=4.38.0->sentence-transformers) (2024.5.15)
# Requirement already satisfied: safetensors>=0.4.1 in /opt/conda/lib/python3.10/site-packages (from transformers<5.0.0,>=4.38.0->sentence-transformers) (0.4.5)
# Requirement already satisfied: tokenizers<0.21,>=0.20 in /opt/conda/lib/python3.10/site-packages (from transformers<5.0.0,>=4.38.0->sentence-transformers) (0.20.0)
# Requirement already satisfied: notebook>=4.4.1 in /opt/conda/lib/python3.10/site-packages (from widgetsnbextension~=3.6.0->ipywidgets) (6.5.7)
# Requirement already satisfied: MarkupSafe>=2.0 in /opt/conda/lib/python3.10/site-packages (from jinja2->torch) (2.1.5)
# Requirement already satisfied: joblib>=1.1.1 in /opt/conda/lib/python3.10/site-packages (from scikit-learn->sentence-transformers) (1.4.2)
# Requirement already satisfied: threadpoolctl>=2.0.0 in /opt/conda/lib/python3.10/site-packages (from scikit-learn->sentence-transformers) (3.5.0)
# Requirement already satisfied: mpmath<1.4,>=1.1.0 in /opt/conda/lib/python3.10/site-packages (from sympy->torch) (1.3.0)
# Requirement already satisfied: parso<0.9.0,>=0.8.3 in /opt/conda/lib/python3.10/site-packages (from jedi>=0.16->ipython>=4.0.0->ipywidgets) (0.8.4)
# Requirement already satisfied: entrypoints in /opt/conda/lib/python3.10/site-packages (from jupyter-client>=6.1.12->ipykernel>=4.5.1->ipywidgets) (0.4)
# Requirement already satisfied: platformdirs>=2.5 in /opt/conda/lib/python3.10/site-packages (from jupyter-core!=5.0.*,>=4.12->ipykernel>=4.5.1->ipywidgets) (3.11.0)
# Requirement already satisfied: argon2-cffi in /opt/conda/lib/python3.10/site-packages (from notebook>=4.4.1->widgetsnbextension~=3.6.0->ipywidgets) (23.1.0)
# Requirement already satisfied: nbformat in /opt/conda/lib/python3.10/site-packages (from notebook>=4.4.1->widgetsnbextension~=3.6.0->ipywidgets) (5.10.4)
# Requirement already satisfied: nbconvert>=5 in /opt/conda/lib/python3.10/site-packages (from notebook>=4.4.1->widgetsnbextension~=3.6.0->ipywidgets) (6.4.5)
# Requirement already satisfied: Send2Trash>=1.8.0 in /opt/conda/lib/python3.10/site-packages (from notebook>=4.4.1->widgetsnbextension~=3.6.0->ipywidgets) (1.8.3)
# Requirement already satisfied: terminado>=0.8.3 in /opt/conda/lib/python3.10/site-packages (from notebook>=4.4.1->widgetsnbextension~=3.6.0->ipywidgets) (0.18.1)
# Requirement already satisfied: prometheus-client in /opt/conda/lib/python3.10/site-packages (from notebook>=4.4.1->widgetsnbextension~=3.6.0->ipywidgets) (0.20.0)
# Requirement already satisfied: nbclassic>=0.4.7 in /opt/conda/lib/python3.10/site-packages (from notebook>=4.4.1->widgetsnbextension~=3.6.0->ipywidgets) (1.1.0)
# Requirement already satisfied: pyparsing!=3.0.5,>=2.0.2 in /opt/conda/lib/python3.10/site-packages (from packaging>=20.9->huggingface-hub>=0.19.3->sentence-transformers) (3.1.2)
# Requirement already satisfied: ptyprocess>=0.5 in /opt/conda/lib/python3.10/site-packages (from pexpect>4.3->ipython>=4.0.0->ipywidgets) (0.7.0)
# Requirement already satisfied: wcwidth in /opt/conda/lib/python3.10/site-packages (from prompt-toolkit<3.1.0,>=3.0.41->ipython>=4.0.0->ipywidgets) (0.2.13)
# Requirement already satisfied: executing>=1.2.0 in /opt/conda/lib/python3.10/site-packages (from stack-data->ipython>=4.0.0->ipywidgets) (2.0.1)
# Requirement already satisfied: asttokens>=2.1.0 in /opt/conda/lib/python3.10/site-packages (from stack-data->ipython>=4.0.0->ipywidgets) (2.4.1)
# Requirement already satisfied: pure-eval in /opt/conda/lib/python3.10/site-packages (from stack-data->ipython>=4.0.0->ipywidgets) (0.2.2)
# Requirement already satisfied: notebook-shim>=0.2.3 in /opt/conda/lib/python3.10/site-packages (from nbclassic>=0.4.7->notebook>=4.4.1->widgetsnbextension~=3.6.0->ipywidgets) (0.2.4)
# Requirement already satisfied: mistune<2,>=0.8.1 in /opt/conda/lib/python3.10/site-packages (from nbconvert>=5->notebook>=4.4.1->widgetsnbextension~=3.6.0->ipywidgets) (0.8.4)
# Requirement already satisfied: jupyterlab-pygments in /opt/conda/lib/python3.10/site-packages (from nbconvert>=5->notebook>=4.4.1->widgetsnbextension~=3.6.0->ipywidgets) (0.3.0)
# Requirement already satisfied: bleach in /opt/conda/lib/python3.10/site-packages (from nbconvert>=5->notebook>=4.4.1->widgetsnbextension~=3.6.0->ipywidgets) (6.1.0)
# Requirement already satisfied: pandocfilters>=1.4.1 in /opt/conda/lib/python3.10/site-packages (from nbconvert>=5->notebook>=4.4.1->widgetsnbextension~=3.6.0->ipywidgets) (1.5.0)
# Requirement already satisfied: testpath in /opt/conda/lib/python3.10/site-packages (from nbconvert>=5->notebook>=4.4.1->widgetsnbextension~=3.6.0->ipywidgets) (0.6.0)
# Requirement already satisfied: defusedxml in /opt/conda/lib/python3.10/site-packages (from nbconvert>=5->notebook>=4.4.1->widgetsnbextension~=3.6.0->ipywidgets) (0.7.1)
# Requirement already satisfied: nbclient<0.6.0,>=0.5.0 in /opt/conda/lib/python3.10/site-packages (from nbconvert>=5->notebook>=4.4.1->widgetsnbextension~=3.6.0->ipywidgets) (0.5.13)
# Requirement already satisfied: fastjsonschema>=2.15 in /opt/conda/lib/python3.10/site-packages (from nbformat->notebook>=4.4.1->widgetsnbextension~=3.6.0->ipywidgets) (2.19.1)
# Requirement already satisfied: jsonschema>=2.6 in /opt/conda/lib/python3.10/site-packages (from nbformat->notebook>=4.4.1->widgetsnbextension~=3.6.0->ipywidgets) (4.22.0)
# Requirement already satisfied: argon2-cffi-bindings in /opt/conda/lib/python3.10/site-packages (from argon2-cffi->notebook>=4.4.1->widgetsnbextension~=3.6.0->ipywidgets) (21.2.0)
# Requirement already satisfied: attrs>=22.2.0 in /opt/conda/lib/python3.10/site-packages (from jsonschema>=2.6->nbformat->notebook>=4.4.1->widgetsnbextension~=3.6.0->ipywidgets) (23.2.0)
# Requirement already satisfied: jsonschema-specifications>=2023.03.6 in /opt/conda/lib/python3.10/site-packages (from jsonschema>=2.6->nbformat->notebook>=4.4.1->widgetsnbextension~=3.6.0->ipywidgets) (2023.12.1)
# Requirement already satisfied: referencing>=0.28.4 in /opt/conda/lib/python3.10/site-packages (from jsonschema>=2.6->nbformat->notebook>=4.4.1->widgetsnbextension~=3.6.0->ipywidgets) (0.35.1)
# Requirement already satisfied: rpds-py>=0.7.1 in /opt/conda/lib/python3.10/site-packages (from jsonschema>=2.6->nbformat->notebook>=4.4.1->widgetsnbextension~=3.6.0->ipywidgets) (0.18.1)
# Requirement already satisfied: jupyter-server<3,>=1.8 in /opt/conda/lib/python3.10/site-packages (from notebook-shim>=0.2.3->nbclassic>=0.4.7->notebook>=4.4.1->widgetsnbextension~=3.6.0->ipywidgets) (2.12.5)
# Requirement already satisfied: cffi>=1.0.1 in /opt/conda/lib/python3.10/site-packages (from argon2-cffi-bindings->argon2-cffi->notebook>=4.4.1->widgetsnbextension~=3.6.0->ipywidgets) (1.16.0)
# Requirement already satisfied: webencodings in /opt/conda/lib/python3.10/site-packages (from bleach->nbconvert>=5->notebook>=4.4.1->widgetsnbextension~=3.6.0->ipywidgets) (0.5.1)
# Requirement already satisfied: pycparser in /opt/conda/lib/python3.10/site-packages (from cffi>=1.0.1->argon2-cffi-bindings->argon2-cffi->notebook>=4.4.1->widgetsnbextension~=3.6.0->ipywidgets) (2.22)
# Requirement already satisfied: anyio>=3.1.0 in /opt/conda/lib/python3.10/site-packages (from jupyter-server<3,>=1.8->notebook-shim>=0.2.3->nbclassic>=0.4.7->notebook>=4.4.1->widgetsnbextension~=3.6.0->ipywidgets) (4.4.0)
# Requirement already satisfied: jupyter-events>=0.9.0 in /opt/conda/lib/python3.10/site-packages (from jupyter-server<3,>=1.8->notebook-shim>=0.2.3->nbclassic>=0.4.7->notebook>=4.4.1->widgetsnbextension~=3.6.0->ipywidgets) (0.10.0)
# Requirement already satisfied: jupyter-server-terminals in /opt/conda/lib/python3.10/site-packages (from jupyter-server<3,>=1.8->notebook-shim>=0.2.3->nbclassic>=0.4.7->notebook>=4.4.1->widgetsnbextension~=3.6.0->ipywidgets) (0.5.3)
# Requirement already satisfied: overrides in /opt/conda/lib/python3.10/site-packages (from jupyter-server<3,>=1.8->notebook-shim>=0.2.3->nbclassic>=0.4.7->notebook>=4.4.1->widgetsnbextension~=3.6.0->ipywidgets) (7.7.0)
# Requirement already satisfied: websocket-client in /opt/conda/lib/python3.10/site-packages (from jupyter-server<3,>=1.8->notebook-shim>=0.2.3->nbclassic>=0.4.7->notebook>=4.4.1->widgetsnbextension~=3.6.0->ipywidgets) (1.8.0)
# Requirement already satisfied: sniffio>=1.1 in /opt/conda/lib/python3.10/site-packages (from anyio>=3.1.0->jupyter-server<3,>=1.8->notebook-shim>=0.2.3->nbclassic>=0.4.7->notebook>=4.4.1->widgetsnbextension~=3.6.0->ipywidgets) (1.3.1)
# Requirement already satisfied: python-json-logger>=2.0.4 in /opt/conda/lib/python3.10/site-packages (from jupyter-events>=0.9.0->jupyter-server<3,>=1.8->notebook-shim>=0.2.3->nbclassic>=0.4.7->notebook>=4.4.1->widgetsnbextension~=3.6.0->ipywidgets) (2.0.7)
# Requirement already satisfied: rfc3339-validator in /opt/conda/lib/python3.10/site-packages (from jupyter-events>=0.9.0->jupyter-server<3,>=1.8->notebook-shim>=0.2.3->nbclassic>=0.4.7->notebook>=4.4.1->widgetsnbextension~=3.6.0->ipywidgets) (0.1.4)
# Requirement already satisfied: rfc3986-validator>=0.1.1 in /opt/conda/lib/python3.10/site-packages (from jupyter-events>=0.9.0->jupyter-server<3,>=1.8->notebook-shim>=0.2.3->nbclassic>=0.4.7->notebook>=4.4.1->widgetsnbextension~=3.6.0->ipywidgets) (0.1.1)
# Requirement already satisfied: fqdn in /opt/conda/lib/python3.10/site-packages (from jsonschema[format-nongpl]>=4.18.0->jupyter-events>=0.9.0->jupyter-server<3,>=1.8->notebook-shim>=0.2.3->nbclassic>=0.4.7->notebook>=4.4.1->widgetsnbextension~=3.6.0->ipywidgets) (1.5.1)
# Requirement already satisfied: isoduration in /opt/conda/lib/python3.10/site-packages (from jsonschema[format-nongpl]>=4.18.0->jupyter-events>=0.9.0->jupyter-server<3,>=1.8->notebook-shim>=0.2.3->nbclassic>=0.4.7->notebook>=4.4.1->widgetsnbextension~=3.6.0->ipywidgets) (20.11.0)
# Requirement already satisfied: jsonpointer>1.13 in /opt/conda/lib/python3.10/site-packages (from jsonschema[format-nongpl]>=4.18.0->jupyter-events>=0.9.0->jupyter-server<3,>=1.8->notebook-shim>=0.2.3->nbclassic>=0.4.7->notebook>=4.4.1->widgetsnbextension~=3.6.0->ipywidgets) (2.4)
# Requirement already satisfied: uri-template in /opt/conda/lib/python3.10/site-packages (from jsonschema[format-nongpl]>=4.18.0->jupyter-events>=0.9.0->jupyter-server<3,>=1.8->notebook-shim>=0.2.3->nbclassic>=0.4.7->notebook>=4.4.1->widgetsnbextension~=3.6.0->ipywidgets) (1.3.0)
# Requirement already satisfied: webcolors>=1.11 in /opt/conda/lib/python3.10/site-packages (from jsonschema[format-nongpl]>=4.18.0->jupyter-events>=0.9.0->jupyter-server<3,>=1.8->notebook-shim>=0.2.3->nbclassic>=0.4.7->notebook>=4.4.1->widgetsnbextension~=3.6.0->ipywidgets) (24.6.0)
# Requirement already satisfied: arrow>=0.15.0 in /opt/conda/lib/python3.10/site-packages (from isoduration->jsonschema[format-nongpl]>=4.18.0->jupyter-events>=0.9.0->jupyter-server<3,>=1.8->notebook-shim>=0.2.3->nbclassic>=0.4.7->notebook>=4.4.1->widgetsnbextension~=3.6.0->ipywidgets) (1.3.0)
# Requirement already satisfied: types-python-dateutil>=2.8.10 in /opt/conda/lib/python3.10/site-packages (from arrow>=0.15.0->isoduration->jsonschema[format-nongpl]>=4.18.0->jupyter-events>=0.9.0->jupyter-server<3,>=1.8->notebook-shim>=0.2.3->nbclassic>=0.4.7->notebook>=4.4.1->widgetsnbextension~=3.6.0->ipywidgets) (2.9.0.20240316)
# Downloading newspaper3k-0.2.8-py3-none-any.whl (211 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 211.1/211.1 kB 12.4 MB/s eta 0:00:00
# Downloading sentence_transformers-3.1.1-py3-none-any.whl (245 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 245.3/245.3 kB 14.6 MB/s eta 0:00:00
# Downloading cssselect-1.2.0-py2.py3-none-any.whl (18 kB)
# Downloading feedparser-6.0.11-py3-none-any.whl (81 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 81.3/81.3 kB 5.6 MB/s eta 0:00:00
# Downloading tldextract-5.1.2-py3-none-any.whl (97 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 97.6/97.6 kB 7.7 MB/s eta 0:00:00
# Downloading requests_file-2.1.0-py2.py3-none-any.whl (4.2 kB)
# Building wheels for collected packages: tinysegmenter, feedfinder2, jieba3k, sgmllib3k
#   Building wheel for tinysegmenter (setup.py) ... done
#   Created wheel for tinysegmenter: filename=tinysegmenter-0.3-py3-none-any.whl size=13538 sha256=e63983edce7475560de97902e31be35957069dc3786b15bd6c60e263d9a81ed9
#   Stored in directory: /root/.cache/pip/wheels/c8/d6/6c/384f58df48c00b9a31d638005143b5b3ac62c3d25fb1447f23
#   Building wheel for feedfinder2 (setup.py) ... done
#   Created wheel for feedfinder2: filename=feedfinder2-0.0.4-py3-none-any.whl size=3340 sha256=fd10a9ac3a0c1be1648131668d19aa49a3e1c5f71e45938b1b125d5dedc99851
#   Stored in directory: /root/.cache/pip/wheels/97/02/e7/a1ff1760e12bdbaab0ac824fae5c1bc933e41c4ccd6a8f8edb
#   Building wheel for jieba3k (setup.py) ... done
#   Created wheel for jieba3k: filename=jieba3k-0.35.1-py3-none-any.whl size=7398382 sha256=a9feff58455d43b253c26c500b1b5075027ba9f0ae48dbe87f18924ae742121e
#   Stored in directory: /root/.cache/pip/wheels/7a/c4/0c/12a9a314ecac499456c4c3b2fcc2f635a3b45a39dfbd240299
#   Building wheel for sgmllib3k (setup.py) ... done
#   Created wheel for sgmllib3k: filename=sgmllib3k-1.0.0-py3-none-any.whl size=6049 sha256=b535f3bdaa60f06e058be1c837fcca30f30a7a2791d049317bbf1df8996c361b
#   Stored in directory: /root/.cache/pip/wheels/f0/69/93/a47e9d621be168e9e33c7ce60524393c0b92ae83cf6c6e89c5
# Successfully built tinysegmenter feedfinder2 jieba3k sgmllib3k
# Installing collected packages: tinysegmenter, sgmllib3k, jieba3k, feedparser, cssselect, requests-file, feedfinder2, tldextract, newspaper3k, sentence-transformers
# Successfully installed cssselect-1.2.0 feedfinder2-0.0.4 feedparser-6.0.11 jieba3k-0.35.1 newspaper3k-0.2.8 requests-file-2.1.0 sentence-transformers-3.1.1 sgmllib3k-1.0.0 tinysegmenter-0.3 tldextract-5.1.2

# %% [markdown]
# ### Importing libraries

# %%
import glob
import pandas as pd
import random
from IPython.display import clear_output
from urllib.parse import urlparse
import os
import re
from newspaper import Article
import time
from bs4 import BeautifulSoup
import torch
from sentence_transformers import SentenceTransformer, util
from tqdm import tqdm

# %% [markdown]
# ### Generating dataframe from json

# %% [markdown]
# Extracting dataframe from json and removing nan

# %%
class FileProcessor:
    def __init__(self, path, attributes):
        self.path = path
        self.attributes = attributes

    def get_content_list(self):
        # Get list of all CSV files in the specified directory
        all_files = glob.glob(self.path + "/*.csv")

        if not all_files:
            raise ValueError(f"No CSV files found in directory: {self.path}")

        li = []

        # Print the files being processed (debugging step)
        print(f"Files found: {all_files}")

        # Iterate over all files
        for filename in all_files:
            try:
                # Read each CSV file with encoding utf-16 and skip bad lines
                df = pd.read_csv(filename, encoding="utf-16", index_col=None, header=0, on_bad_lines='skip')

                # Handle missing columns by checking against the given attributes list
                if all(attr in df.columns for attr in self.attributes):

                    # Add a new column with the filename
                    df['filename'] = os.path.basename(filename).replace('.csv', '')                   # Extract just the file name from the path

                    # Reorder columns: filename at the beginning + attributes
                    df = df[['filename'] + self.attributes]

                    li.append(df)
                else:
                    print(f"Skipping file {filename} due to missing columns.")
            except PermissionError:
                print(f"Permission denied for file {filename}. Skipping.")
            except Exception as e:
                print(f"Error reading file {filename}: {e}")

        # If no valid dataframes have been collected, raise an error
        if not li:
            raise ValueError("No valid CSV files could be read.")

        # Concatenate all DataFrames into a single DataFrame
        frame = pd.concat(li, axis=0, ignore_index=True)

        # Return the DataFrame as well if further processing is needed
        return frame

# %%
# Load the dataframe
processor = FileProcessor(path="../starting_datasets/EN/", attributes=["message", "post_type", "link"])
df = processor.get_content_list()
# Out:
# Files found: ['../starting_dataset/EN\\abc.csv', '../starting_dataset/EN\\bbc.csv', '../starting_dataset/EN\\cbs.csv', '../starting_dataset/EN\\cnn.csv', '../starting_dataset/EN\\fox.csv', '../starting_dataset/EN\\foxandfriends.csv', '../starting_dataset/EN\\huffington.csv', '../starting_dataset/EN\\latimes.csv', '../starting_dataset/EN\\nbc.csv', '../starting_dataset/EN\\npr.csv', '../starting_dataset/EN\\nytimes.csv', '../starting_dataset/EN\\time.csv', '../starting_dataset/EN\\usatoday.csv', '../starting_dataset/EN\\washington.csv', '../starting_dataset/EN\\wsj.csv']

# %%
#Check the dataframe
df.head()
# Out:
#   filename                                            message post_type  \
# 0      abc  Roberts took the unusual step of devoting the ...      link
# 1      abc                     Do you agree with the new law?      link
# 2      abc  Some pretty cool confetti will rain down on Ne...      link
# 3      abc                                                NaN      link
# 4      abc  The pharmacy was held up by a man seeking pres...      link
#
#                                                 link
# 0  http://abcnews.go.com/blogs/headlines/2011/12/...
# 1  http://abcnews.go.com/blogs/politics/2011/12/w...
# 2  http://abcnews.go.com/blogs/headlines/2011/12/...
# 3  http://abcnews.go.com/blogs/politics/2011/12/m...
# 4  http://abcnews.go.com/US/ny-pharmacy-shootout-...

# %%
# Filter the DataFrame to keep only the rows where 'post_type' is exactly 'link', ignoring leading/trailing spaces and case sensitivity
df_filtered = df[df['post_type'].str.strip().str.lower().eq('link'.lower())]

# %%
# Replace empty strings with pd.NA
df_filtered = df_filtered.copy()
df_filtered.replace("", pd.NA, inplace=True)

# Replace 'nan' and '<na>' strings with pd.NA
df_filtered.replace(['nan', '<na>'], pd.NA, inplace=True)

# %%
len(df_filtered)
# Out:
# 427479

# %%
df_filtered = df.dropna()

# %%
len(df_filtered)
# Out:
# 512052

# %%
df_filtered.head()
# Out:
#   filename                                            message post_type  \
# 0      abc  Roberts took the unusual step of devoting the ...      link
# 1      abc                     Do you agree with the new law?      link
# 2      abc  Some pretty cool confetti will rain down on Ne...      link
# 4      abc  The pharmacy was held up by a man seeking pres...      link
# 6      abc  There were no immediate reports of damage or i...      link
#
#                                                 link
# 0  http://abcnews.go.com/blogs/headlines/2011/12/...
# 1  http://abcnews.go.com/blogs/politics/2011/12/w...
# 2  http://abcnews.go.com/blogs/headlines/2011/12/...
# 4  http://abcnews.go.com/US/ny-pharmacy-shootout-...
# 6  http://abcnews.go.com/International/wireStory/...

# %%
# Remove rows where the number of words (space-separated) in the specified column is greater than 1
df_filtered = df_filtered[df_filtered['link'].str.split().str.len() <= 1]
df_filtered = df_filtered[df_filtered['link'].str.split().str.len() == 1]

# %%
len(df_filtered)
# Out:
# 512049

# %%
df_filtered.head()
# Out:
#   filename                                            message post_type  \
# 0      abc  Roberts took the unusual step of devoting the ...      link
# 1      abc                     Do you agree with the new law?      link
# 2      abc  Some pretty cool confetti will rain down on Ne...      link
# 4      abc  The pharmacy was held up by a man seeking pres...      link
# 6      abc  There were no immediate reports of damage or i...      link
#
#                                                 link
# 0  http://abcnews.go.com/blogs/headlines/2011/12/...
# 1  http://abcnews.go.com/blogs/politics/2011/12/w...
# 2  http://abcnews.go.com/blogs/headlines/2011/12/...
# 4  http://abcnews.go.com/US/ny-pharmacy-shootout-...
# 6  http://abcnews.go.com/International/wireStory/...

# %%
# Drop the 'post_type' column from the DataFrame
df_filtered = df_filtered.drop(columns='post_type')

# %%
df_filtered.head()
# Out:
#   filename                                            message  \
# 0      abc  Roberts took the unusual step of devoting the ...
# 1      abc                     Do you agree with the new law?
# 2      abc  Some pretty cool confetti will rain down on Ne...
# 4      abc  The pharmacy was held up by a man seeking pres...
# 6      abc  There were no immediate reports of damage or i...
#
#                                                 link
# 0  http://abcnews.go.com/blogs/headlines/2011/12/...
# 1  http://abcnews.go.com/blogs/politics/2011/12/w...
# 2  http://abcnews.go.com/blogs/headlines/2011/12/...
# 4  http://abcnews.go.com/US/ny-pharmacy-shootout-...
# 6  http://abcnews.go.com/International/wireStory/...

# %% [markdown]
# ### Getting real urls
# Let's take additional steps so that we don't make too many requests

# %%
# Extract the top-level domain from each URL
df_filtered['top_level_domain'] = df_filtered['link'].apply(lambda url: f"{urlparse(url).scheme}://{urlparse(url).netloc}" if pd.notna(url) else pd.NA)

# Get the unique top-level domains and remove NaN values
unique_domains = pd.Series(df_filtered['top_level_domain'].unique()).dropna()

# %%
df_filtered.head()
# Out:
#   filename                                            message  \
# 0      abc  Roberts took the unusual step of devoting the ...
# 1      abc                     Do you agree with the new law?
# 2      abc  Some pretty cool confetti will rain down on Ne...
# 4      abc  The pharmacy was held up by a man seeking pres...
# 6      abc  There were no immediate reports of damage or i...
#
#                                                 link       top_level_domain
# 0  http://abcnews.go.com/blogs/headlines/2011/12/...  http://abcnews.go.com
# 1  http://abcnews.go.com/blogs/politics/2011/12/w...  http://abcnews.go.com
# 2  http://abcnews.go.com/blogs/headlines/2011/12/...  http://abcnews.go.com
# 4  http://abcnews.go.com/US/ny-pharmacy-shootout-...  http://abcnews.go.com
# 6  http://abcnews.go.com/International/wireStory/...  http://abcnews.go.com

# %%
len(unique_domains)
# Out:
# 1018

# %%
# Function to get the final URL after following redirects
def get_final_url(url):
    try:
        response = requests.head(url, allow_redirects=True, timeout=10)
        final_url = response.url
        # Parse and return the scheme and netloc (domain)
        parsed_url = urlparse(final_url)
        return f"{parsed_url.scheme}://{parsed_url.netloc}"
    except requests.RequestException:
        return pd.NA

# %%
# Process the list of URLs and extract the final domains
final_domains = [get_final_url(url) for url in unique_domains]

# %%
len(final_domains)
# Out:
# 1018

# %%
# Get the final domains to manually check the correctness to avoid unnecessary requests and problems with fake domains
final_domains
# Out:
# ['https://abcnews.go.com',
#  'http://abcn.ws',
#  'http://getglue.com',
#  'https://www.snappytv.com',
#  'https://www.theknot.com',
#  'https://www.facebook.com',
#  'https://www.espnfrontrow.com',
#  'https://www.goodmorningamerica.com',
#  'http://news.yahoo.com',
#  'https://bitly.com',
#  'https://www.yahoo.com',
#  'https://www.youtube.com',
#  'http://espn.go.com',
#  'https://www.pinterest.com',
#  <NA>,
#  'http://abcnewsradioonline.com',
#  <NA>,
#  'https://www.instagram.com',
#  'https://t.co',
#  'http://trib.al',
#  'http://bitly.com',
#  'https://www.youtube.com',
#  <NA>,
#  'https://www.goodmorningamerica.com',
#  'http://www.espn.com',
#  'https://www.youtube.com',
#  'https://abcnews.go.com',
#  'https://abc7news.com',
#  'https://abc7.com',
#  'https://abc7chicago.com',
#  'https://abc7ny.com',
#  'https://abc7ny.com',
#  'https://giphy.com',
#  'https://giphy.com',
#  'https://vote.webbyawards.com',
#  'http://trib.al',
#  'https://abc11.com',
#  'https://abc13.com',
#  'https://www.bbc.co.uk',
#  'https://audioboo.fm',
#  'https://www.bbc.co.uk',
#  'https://www.bbc.com',
#  <NA>,
#  'https://www.instagram.com',
#  'https://vine.co',
#  'https://vote.webbyawards.com',
#  'https://vine.co:443',
#  'https://snpy.tv',
#  'https://www.bbc.com',
#  'https://i.makeagif.com',
#  'https://64.media.tumblr.com',
#  'https://64.media.tumblr.com',
#  'https://www.instagram.com',
#  'https://media.giphy.com',
#  'https://makeagif.com',
#  'https://www.cbsnews.com',
#  'https://www.cbsnews.com',
#  'https://www.hootsuite.com',
#  'https://www.cnet.com',
#  'https://www.cbsnews.com',
#  <NA>,
#  'https://www.cbsnews.com',
#  'https://www.cbsnews.com',
#  'https://www.cbssports.com',
#  'https://www.cbs.com',
#  'https://www.cbsnews.com',
#  'https://www.cbsnews.com',
#  'https://www.socialnewsdesk.com',
#  'https://www.socialnewsdesk.com',
#  <NA>,
#  'https://www.cbsnews.com',
#  'https://66.media.tumblr.com',
#  'https://64.media.tumblr.com',
#  'https://edition.cnn.com',
#  'https://bitly.com',
#  'https://edition.cnn.com',
#  'http://politicalticker.blogs.cnn.com',
#  'http://religion.blogs.cnn.com',
#  'http://lightyears.blogs.cnn.com',
#  'http://news.blogs.cnn.com',
#  'http://whatsnext.blogs.cnn.com',
#  'http://ac360.blogs.cnn.com',
#  'https://edition.cnn.com',
#  'https://edition.cnn.com',
#  'http://thechart.blogs.cnn.com',
#  'http://piersmorgan.blogs.cnn.com',
#  'http://cnnphotos.blogs.cnn.com',
#  'http://geekout.blogs.cnn.com',
#  'http://inamerica.blogs.cnn.com',
#  'https://edition.cnn.com',
#  'http://schoolsofthought.blogs.cnn.com',
#  <NA>,
#  'https://cnnpressroom.blogs.cnn.com',
#  'http://outfront.blogs.cnn.com',
#  'http://security.blogs.cnn.com',
#  'http://finance.fortune.cnn.com',
#  'http://globalpublicsquare.blogs.cnn.com',
#  'http://cnnradio.cnn.com',
#  <NA>,
#  'http://management.fortune.cnn.com',
#  <NA>,
#  'https://edition.cnn.com',
#  'https://giphy.com',
#  'http://pubx.ch',
#  'https://www.ozy.com',
#  'https://www.rollingstone.com',
#  'https://www.reddit.com',
#  'http://on.hln.tv',
#  'https://edition.cnn.com',
#  'https://bleacherreport.com',
#  'https://wordpress.com',
#  'https://us.cnn.com',
#  <NA>,
#  'https://bleacherreport.com',
#  <NA>,
#  'http://i2.cdn.turner.com',
#  'http://i.giphy.com',
#  'http://gph.is',
#  'https://www.foxnews.com',
#  'https://www.foxnews.com',
#  'https://www.foxnews.com',
#  'https://www.facebook.com',
#  'https://www.foxbusiness.com',
#  'https://twitter.com',
#  'https://www.apple.com',
#  <NA>,
#  'https://twitter.com',
#  <NA>,
#  'https://radio.foxnews.com',
#  'https://www.foxnews.com',
#  'https://www.foxnews.com',
#  'https://nation.foxnews.com',
#  'https://www.foxnews.com',
#  'https://tinyurl.com',
#  'https://www.foxbusiness.com',
#  <NA>,
#  'https://foxnews.shop',
#  'https://www.foxnews.com',
#  'https://www.fox29.com',
#  'https://www.fox5ny.com',
#  'https://www.foxnews.com',
#  'https://www.mediaite.com',
#  'http://fox59.com',
#  'http://fox4kc.com',
#  'https://variety.com',
#  'https://www.foxnews.com',
#  'https://radio.foxnews.com',
#  'https://www.eventbrite.com',
#  <NA>,
#  'https://vimeo.com',
#  'https://www.alexslemonade.org:443',
#  'https://www.rodneyatkins.com',
#  'https://www.thegameshowsource.com',
#  'https://open.spotify.com',
#  <NA>,
#  'https://www.amazon.com',
#  'https://t.co',
#  'https://www.toddstarnes.com',
#  'https://www.huffpost.com',
#  'https://elections.huffingtonpost.com',
#  'https://mashable.com',
#  'http://gadling.com',
#  'https://www.5min.com',
#  'https://www.huffingtonpost.co.uk',
#  'https://www.huffpost.com',
#  'https://vimeo.com',
#  'https://www.aol.com',
#  'https://eu.usatoday.com',
#  'https://www.moviefone.com',
#  'http://www.huffingtonmagazine.com',
#  <NA>,
#  'http://online.wsj.com',
#  'https://thunderclap.it',
#  'https://video.ibm.com',
#  'https://www.nytimes.com',
#  'https://www.reuters.com',
#  <NA>,
#  'https://techcrunch.com',
#  'https://www.huffpost.com',
#  'https://www.huffpost.com',
#  'https://www.engadget.com',
#  'https://hpsandy.crowdmap.com',
#  'https://www.nhc.noaa.gov',
#  'https://www.disasterassistance.gov',
#  'https://www.redcross.org',
#  'https://www.nybc.org',
#  'https://www.americares.org',
#  'https://www.feedingamerica.org',
#  'http://www.msnbc.msn.com',
#  'https://huffpostpolitics.tumblr.com',
#  'https://www.apple.com',
#  'http://app.votewithfriends.net',
#  'https://patch.com',
#  'https://www.wsj.com',
#  'https://data.huffingtonpost.com',
#  'https://www.gofundme.com:443',
#  'https://www.huffpost.com',
#  'https://www.huffpost.com',
#  'http://huff.lv',
#  'https://www.aol.com',
#  'http://huff.to',
#  'https://nymag.com',
#  'https://www.vulture.com',
#  'https://www.cracked.com',
#  'https://www.newyorker.com',
#  'https://www.motherjones.com',
#  'https://projects.huffingtonpost.com',
#  'https://www.theguardian.com',
#  'http://www.parade.com',
#  'https://www.rawstory.com',
#  'https://www.theatlantic.com',
#  'https://ftw.usatoday.com',
#  'https://www.nbcnews.com',
#  'https://slate.com',
#  'https://www.esquire.com',
#  'https://www.buzzfeed.com',
#  'https://theonion.com',
#  'https://www.nydailynews.com',
#  'https://www.hollywoodreporter.com',
#  'https://www.newser.com',
#  'https://www.popularmechanics.com',
#  'https://www.salon.com',
#  'https://signup.dropout.tv',
#  <NA>,
#  <NA>,
#  'https://www.huffpost.com',
#  'https://thebolditalic.com',
#  'https://elezea.com',
#  'https://www.telegraph.co.uk',
#  'https://www.businessinsider.com',
#  'https://www.fastcodesign.com',
#  'https://thoughtcatalog.com',
#  'https://www.upworthy.com',
#  'http://viralnova.com',
#  'https://www.yourtango.com',
#  'https://time.com',
#  'https://www.fastcompany.com',
#  <NA>,
#  <NA>,
#  'https://www.mentalfloss.com',
#  'https://www.cosmopolitan.com',
#  'https://uproxx.com',
#  'https://laughingsquid.com',
#  'https://www.womenshealthmag.com',
#  'http://www.thedailybeast.com',
#  'https://www.today.com',
#  'https://www.rollingstone.com',
#  'https://deadspin.com',
#  'https://www.ebaumsworld.com:443',
#  <NA>,
#  'https://www.someecards.com',
#  'https://www.silive.com',
#  'http://www.scientificamerican.com',
#  'http://www.dailydot.com',
#  'https://www.vice.com',
#  'https://www.boredpanda.com',
#  'https://www.npr.org',
#  'https://pulptastic.com',
#  'https://www.mentalfloss.com',
#  'https://gawker.com',
#  'https://www.bustle.com',
#  'https://eu.usatoday.com',
#  'https://toronto.ctvnews.ca',
#  'https://www.people.com',
#  'https://www.iflscience.com',
#  'https://www.avclub.com',
#  'https://www.elitedaily.com',
#  'http://www.seattlepi.com',
#  'https://gizmodo.com',
#  'https://www.newsday.com',
#  'https://www.jezebel.com',
#  'http://www.takepart.com',
#  'https://firstwefeast.com',
#  'https://www.wired.com',
#  'https://billingsgazette.com',
#  'https://www.politico.com',
#  'https://www.pinterest.com',
#  'https://thinkprogress.org',
#  'https://www.baltimoresun.com',
#  'https://www.nytimes.com',
#  'https://www.msnbc.com',
#  'https://www.adweek.com',
#  'https://www.latimes.com',
#  'https://sfglobe.com:443',
#  'https://qz.com',
#  'https://modernfarmer.com',
#  'http://hellogiggles.com',
#  'https://www.thedodo.com',
#  'https://www.forbes.com',
#  'http://www.thefader.com',
#  'https://globalpost.com',
#  'https://aeon.co',
#  'https://archive.nytimes.com',
#  'https://www.nationalgeographic.com',
#  'https://funnyordie.com',
#  'https://www.fastcoexist.com',
#  'https://www.bonappetit.com',
#  'https://www.nationalgeographic.com',
#  'https://www.gq.com',
#  'https://www.mic.com',
#  'https://www.nationalgeographic.com',
#  <NA>,
#  <NA>,
#  'https://newrepublic.com',
#  'https://www.bostonglobe.com',
#  'https://www.thecut.com',
#  'http://www.geekwire.com',
#  'https://www.vox.com',
#  <NA>,
#  'https://www.thefrisky.com',
#  'https://www.smithsonianmag.com',
#  'https://www.thestranger.com',
#  'http://www.opposingviews.com',
#  'https://www.sadanduseless.com',
#  'https://arstechnica.com:443',
#  'https://kstp.com',
#  'https://www.theverge.com',
#  'http://www.clutchmagonline.com',
#  'https://www.nerve.com',
#  'https://www.vanityfair.com',
#  'https://www.nytimes.com',
#  'https://www.thrillist.com',
#  'https://www.technologyreview.com',
#  'https://gothamist.com',
#  <NA>,
#  'https://time.com',
#  'https://www.climatecentral.org',
#  'https://news.nationalgeographic.org',
#  'https://www.si.com',
#  'https://www.katv.com',
#  'https://www.aclu.org',
#  'https://eu.desertsun.com',
#  'https://medium.com',
#  'https://www.wtvm.com',
#  <NA>,
#  'https://food52.com',
#  'http://www.independent.co.uk',
#  'https://www.nationalgeographic.com',
#  'https://www.mtv.com',
#  'https://www.distractify.com',
#  'https://www.mlive.com',
#  'https://archive.nytimes.com',
#  'https://bitchmagazine.org',
#  'https://ensia.com',
#  'http://www.vocativ.com',
#  'https://www.nytimes.com',
#  'https://www.vice.com',
#  'https://www.dotdashmeredith.com',
#  'https://eu.naplesnews.com',
#  'http://www.brainpickings.org',
#  'https://9gag.com',
#  'https://www.propublica.org',
#  'https://www.realsimple.com',
#  <NA>,
#  'https://www.nytimes.com',
#  'https://www.nationalgeographic.com',
#  'https://pornburger.me',
#  'https://www.texasmonthly.com',
#  'https://newrepublic.com',
#  'http://www.foodnetwork.com',
#  'https://www.propublica.org',
#  'https://ghostinthedata.com',
#  'http://rankings.gawker.com',
#  'https://www.eater.com',
#  <NA>,
#  'https://grist.org',
#  'https://www.vogue.com',
#  'https://www.outsideonline.com',
#  'https://www.demilked.com',
#  'https://www.rookiemag.com',
#  'http://nationswell.com',
#  'http://www.thekitchn.com',
#  <NA>,
#  'https://www.vice.com',
#  'https://www.bloomberg.com',
#  'https://www.elle.com',
#  <NA>,
#  'https://archive.nytimes.com',
#  'https://rewirenewsgroup.com',
#  'http://www.pixable.com',
#  'https://cafe.com',
#  'https://www.flavorwire.com',
#  <NA>,
#  'https://fortune.com',
#  <NA>,
#  'https://www.dotdashmeredith.com',
#  'https://digg.com',
#  'https://uproxx.com',
#  'https://www.babycenter.com',
#  'https://www.askmen.com',
#  'https://www.vice.com',
#  'https://archive.nytimes.com',
#  'https://www.popsci.com',
#  'https://www.parents.com',
#  'https://www.harpersbazaar.com',
#  'https://www.atlasobscura.com',
#  'http://wxch.nl',
#  'https://www.wsj.com',
#  'http://blog.foreignpolicy.com',
#  'https://www.stylemepretty.com',
#  'https://www.scarymommy.com',
#  'https://bitly.com',
#  'http://www.seattleweekly.com',
#  'https://theoatmeal.com:443',
#  'https://www.laphamsquarterly.org',
#  'https://www.huffpost.com',
#  'https://www.aol.com',
#  'https://www.wsj.com',
#  'http://on.wsj.com',
#  'https://longform.org',
#  <NA>,
#  'https://www.nytimes.com',
#  'https://www.nationalgeographic.com',
#  'https://www.dotdashmeredith.com',
#  'https://www.treehugger.com:443',
#  'https://weather.com',
#  'http://www.theawl.com',
#  'http://hint.fm',
#  'https://www.6sqft.com',
#  'http://coed.com',
#  'http://feministing.com',
#  'https://www.refinery29.com',
#  'https://www.thisiscolossal.com',
#  <NA>,
#  'https://janetmock.com',
#  'https://www.firstlook.media',
#  'https://www.autostraddle.com',
#  'https://www.grubstreet.com',
#  'http://slate.me',
#  'https://theworld.org',
#  'http://www.hopesandfears.com',
#  'https://themighty.com',
#  'https://www.eater.com',
#  'https://www.huffingtonpost.fr',
#  'https://thenib.com',
#  'https://www.seattlemet.com',
#  'https://www.saveur.com',
#  <NA>,
#  'https://psmag.com',
#  'https://longreads.com',
#  'https://welcome.pubexchange.com',
#  'https://aaronbleyaert.tumblr.com',
#  <NA>,
#  <NA>,
#  'https://www.huffingtonpost.es',
#  'https://www.bloomberg.com',
#  'http://www.treehugger.com',
#  'http://the-toast.net',
#  'http://linkis.com',
#  'https://talkingpointsmemo.com',
#  'http://howfarfromhome.com',
#  'http://trib.al',
#  'https://www.purewow.com',
#  'https://www.huffingtonpost.gr',
#  'https://adage.com',
#  <NA>,
#  'https://www.upworthy.com',
#  'https://www.usmagazine.com',
#  'http://diply.com',
#  'https://www.huffpost.com',
#  'https://www.mandatory.com',
#  'https://www.fatherly.com',
#  'https://testkitchen.huffingtonpost.com',
#  'https://www.huffpost.com',
#  'https://www.inverse.com',
#  'https://eko.com',
#  'https://www.huffpost.com',
#  'https://www.thrillist.com',
#  'https://www.tastingtable.com',
#  'https://www.mic.com',
#  'https://www.latimes.com',
#  'https://www.latimes.com',
#  'https://www.latimes.com',
#  'https://www.latimes.com',
#  'https://notices.californiatimes.com',
#  'https://www.latimes.com',
#  'http://events.latimes.com',
#  'https://www.latimes.com',
#  'https://www.latimes.com',
#  'https://www.eventbrite.com',
#  'https://notices.californiatimes.com',
#  'http://www.ktla.com',
#  'https://notices.californiatimes.com',
#  'https://www.latimes.com',
#  'https://notices.californiatimes.com',
#  'https://accounts.google.com',
#  'https://www.courant.com',
#  'https://notices.californiatimes.com',
#  'https://furm.com',
#  <NA>,
#  'https://www.commuterama.com',
#  'https://www.latimes.com:443',
#  'https://soundcloud.com',
#  'https://www.thinglink.com',
#  'https://notices.californiatimes.com',
#  <NA>,
#  <NA>,
#  'https://latimespast.tumblr.com',
#  'http://nextly.com',
#  <NA>,
#  'https://www.sun-sentinel.com',
#  'https://www.thinglink.com:443',
#  'https://www.latimes.com',
#  'https://www.latimes.com',
#  'https://homicide.latimes.com',
#  'https://notices.californiatimes.com',
#  'http://fw.to',
#  'https://notices.californiatimes.com',
#  'https://www.youtube.com',
#  <NA>,
#  'https://www.periscope.tv',
#  <NA>,
#  'https://www.hoylosangeles.com',
#  'https://notices.californiatimes.com',
#  'https://notices.californiatimes.com',
#  <NA>,
#  <NA>,
#  'https://we-are-la.tumblr.com',
#  'https://www.reddit.com',
#  'https://membership.latimes.com',
#  'http://video.msnbc.msn.com',
#  'http://usnews.msnbc.msn.com',
#  'http://firstread.msnbc.msn.com',
#  'https://www.nbcsports.com',
#  'http://video.today.msnbc.msn.com',
#  'http://elections.msnbc.msn.com',
#  'http://nbcpolitics.msnbc.msn.com',
#  'http://photoblog.msnbc.msn.com',
#  'http://worldnews.msnbc.msn.com',
#  'http://presspass.msnbc.msn.com',
#  'http://bottomline.msnbc.msn.com',
#  'http://behindthewall.msnbc.msn.com',
#  'http://entertainment.msnbc.msn.com',
#  'http://vitals.msnbc.msn.com',
#  'http://overheadbin.msnbc.msn.com',
#  'http://technolog.msnbc.msn.com',
#  'http://worldblog.msnbc.msn.com',
#  'http://cosmiclog.msnbc.msn.com',
#  'https://www.nbcnews.com',
#  'http://scores.nbcsports.msnbc.com',
#  'https://www.nbcsports.com',
#  'http://dailynightly.msnbc.msn.com',
#  'http://animaltracks.today.msnbc.msn.com',
#  'http://today.msnbc.msn.com',
#  'http://rockcenter.msnbc.msn.com',
#  'http://digitallife.today.msnbc.msn.com',
#  'http://openchannel.msnbc.msn.com',
#  'https://www.nbcsports.com',
#  'https://www.nbcnewyork.com',
#  'http://todayentertainment.today.msnbc.msn.com',
#  'http://insidedateline.msnbc.msn.com',
#  'http://www.gadgetbox.msnbc.msn.com',
#  'http://economywatch.msnbc.msn.com',
#  'http://lifeinc.today.msnbc.msn.com',
#  'http://redtape.msnbc.msn.com',
#  'http://todaytravel.today.msnbc.msn.com',
#  'http://todayhealth.today.msnbc.msn.com',
#  'http://hqplayer.nbcsports.com',
#  <NA>,
#  'http://hiringourheroes.today.msnbc.msn.com',
#  'http://www.technolog.msnbc.msn.com',
#  'https://www.nbcdfw.com',
#  'http://marketday.msnbc.msn.com',
#  'https://www.nbcsports.com',
#  'https://www.cnbc.com',
#  <NA>,
#  'https://www.nbcchicago.com',
#  'https://www.nbclosangeles.com',
#  'http://todayinlondonblog.today.msnbc.msn.com',
#  'http://itineraries.msnbc.msn.com',
#  'https://www.nbcolympics.com',
#  'http://allday.today.msnbc.msn.com',
#  'http://bodyodd.msnbc.msn.com',
#  'https://www.nbcsports.com',
#  'http://theclicker.today.msnbc.msn.com',
#  'https://www.nbcnews.com',
#  'http://leanforward.msnbc.msn.com',
#  'https://www.nbcnews.com',
#  'https://www.nbcsandiego.com',
#  'https://www.nbcphiladelphia.com',
#  'https://www.nbcnews.com',
#  'http://www.9news.com',
#  'https://www.nbcnews.com',
#  'https://www.nbcnews.com',
#  'http://marketday.nbcnews.com',
#  'https://www.nbcnews.com',
#  <NA>,
#  <NA>,
#  'https://www.nbcnews.com',
#  'http://www.wbaltv.com',
#  'https://www.nbcnews.com',
#  'https://www.nbcnews.com',
#  'http://www.futureoftech.msnbc.msn.com',
#  'https://www.nbcnews.com',
#  'http://thegrio.com',
#  <NA>,
#  'https://www.nbcnews.com',
#  'https://www.nbcnews.com',
#  <NA>,
#  'https://www.today.com',
#  'https://www.nbcnews.com',
#  <NA>,
#  'https://www.nbcnews.com',
#  'http://www.kxan.com',
#  'http://www.parenttoolkit.com',
#  'https://www.clickondetroit.com',
#  <NA>,
#  <NA>,
#  'https://www.today.com',
#  'https://www.nbcnews.com',
#  'https://www.today.com',
#  'https://www.nbcsports.com',
#  <NA>,
#  <NA>,
#  'https://www.nbcnews.com',
#  <NA>,
#  'https://www.nbcbayarea.com',
#  'https://www.nbcnews.com',
#  'https://www.vox.com',
#  'https://www.nbcsports.com',
#  'https://www.nbcsports.com',
#  'https://www.nbcwashington.com',
#  <NA>,
#  <NA>,
#  'https://www.nbcsports.com',
#  'https://media12.s-nbcnews.com:443',
#  'http://trib.al',
#  'https://trib.al:443',
#  'http://on.today.com',
#  'https://www.nbcsports.com',
#  'https://www.nbcsports.com',
#  'https://www.nbcsports.com',
#  <NA>,
#  'https://www.necn.com',
#  'https://trib.al:443',
#  'http://trib.al',
#  'https://www.nbcsports.com',
#  'https://www.today.com',
#  'https://www.nbcnews.com',
#  'https://www.nbcsportschicago.com',
#  'https://www.nbcsports.com',
#  'https://nascartalk.nbcsports.com',
#  'https://www.nbcconnecticut.com',
#  'https://weather.com',
#  'https://www.nbcsports.com',
#  'https://www.nbcsports.com',
#  'https://www.nbcsports.com',
#  <NA>,
#  'https://www.nbcsports.com',
#  'https://trib.al:443',
#  'https://www.nbcsports.com',
#  'https://time.com',
#  'https://www.nbcsports.com',
#  'https://www.nbcsports.com',
#  'https://www.nbcnews.com',
#  'https://globalpost.com',
#  'https://www.msnbc.com',
#  'https://www.nbcsportsbayarea.com',
#  'https://www.nbcsports.com',
#  'https://www.nbcsports.com',
#  <NA>,
#  'https://www.today.com',
#  'https://stateimpact.npr.org',
#  'https://snapjudgment.org',
#  'https://www.americanpublicmedia.org',
#  'http://opentodebate.org',
#  'https://www.americanpublicmedia.org',
#  'https://www.nprsurveys.org',
#  'https://blog.apps.npr.org',
#  'https://www.wbur.org',
#  <NA>,
#  <NA>,
#  'https://laist.com',
#  'https://www.kqed.org',
#  'https://www.kqed.org:443',
#  'https://soundcloud.com',
#  'http://elections2012.npr.org',
#  'https://www.kqed.org:443',
#  'http://www.ticketweb.com',
#  'https://www.wnycstudios.org',
#  'https://inauguration2013.tumblr.com',
#  'https://www.wbur.org',
#  'https://storycorps.org',
#  'https://www.wbur.org',
#  'https://www.kqed.org',
#  'https://www.wbur.org',
#  <NA>,
#  'https://www.opb.org',
#  'http://www.ktoo.org',
#  'https://dinnertimeconfessional.tumblr.com',
#  <NA>,
#  'https://www.wlrn.org',
#  'https://wamu.org',
#  'https://www.lpm.org',
#  'https://www.michiganpublic.org',
#  'https://www.wesa.fm',
#  'https://www.stlpr.org',
#  'https://www.kuow.org:443',
#  'https://www.kcur.org',
#  'https://www.kunc.org',
#  <NA>,
#  'https://www.wbur.org',
#  'https://www.npr.org',
#  'https://thatssomiami.tumblr.com',
#  'https://cookyourcupboard.tumblr.com',
#  'https://st6423.customervoice360.com',
#  'https://www.npr.org',
#  'http://www.kickstarter.com',
#  'https://www.optimalworkshop.com',
#  'https://she-works.tumblr.com',
#  'https://theracecardproject.com',
#  'https://www.boisestatepublicradio.org',
#  'http://thekey.xpn.org',
#  'https://www.wbur.org',
#  'https://www.mpr.org',
#  'https://www.kalw.org',
#  <NA>,
#  'https://www.kuer.org',
#  'https://www.mpr.org',
#  'https://www.kuer.org',
#  'https://ari-in-africa.tumblr.com',
#  'http://www.quirksee.org',
#  <NA>,
#  'https://stateofopportunity.michiganradio.org',
#  'https://returntoiowa.tumblr.com',
#  <NA>,
#  'https://npr.tumblr.com',
#  'https://www.mprnews.org',
#  'https://consideringbrazil.tumblr.com',
#  'https://kindworld.tumblr.com',
#  'http://npr.trib.al',
#  'https://www.kut.org',
#  'https://wamu.org',
#  'http://nashvillepublicradio.org',
#  <NA>,
#  'https://www.prx.org',
#  'https://www.wuwm.com',
#  'https://www.keranews.org',
#  'https://www.wgbh.org',
#  'https://www.ctpublic.org',
#  'https://news.wjct.org',
#  'https://www.kpbs.org',
#  'http://wvpublic.org',
#  'https://www.vermontpublic.org',
#  'https://www.thecurrent.org',
#  'https://www.vermontpublic.org',
#  'http://ww38.lobbyingmissouri.org',
#  'http://artandseek.net',
#  <NA>,
#  'http://breakthroughs.kera.org',
#  'http://opentodebate.org',
#  'http://nationaldayoflistening.org',
#  'https://www.paramountplus.com',
#  'https://projects.scpr.org',
#  'https://www.mprnews.org',
#  'https://bitly.com',
#  'http://mprne.ws',
#  'https://endoftheroad95.tumblr.com',
#  'https://www.wesa.fm',
#  'https://npr8.tumblr.com',
#  'https://nprontheroad.tumblr.com',
#  'https://www.kqed.org',
#  'https://nprchives.tumblr.com',
#  'https://nprinterns.tumblr.com',
#  'https://developers.googleblog.com',
#  'http://earthfix.info',
#  <NA>,
#  'https://www.wunc.org',
#  'https://www.kunc.org',
#  'http://stlpublicradio.github.io',
#  'https://www.wbur.org',
#  <NA>,
#  'http://projects.wgbhnews.org',
#  'https://bitly.com',
#  'http://bandwidth.wamu.org',
#  'https://www.cpr.org',
#  'https://www.wbez.org',
#  'https://about.meta.com',
#  'https://www.reddit.com',
#  <NA>,
#  'https://skunkbear.tumblr.com',
#  'https://interactive.wbez.org',
#  'http://hiddencolorado.kunc.org',
#  'http://redd.it',
#  'https://carolinatheatre.org',
#  'http://generationone.kera.org',
#  'https://nprcodeswitch.tumblr.com',
#  'https://www.wnyc.org',
#  'https://crowdsignal.com',
#  'https://thebeaker.org',
#  'https://tinydeskcontest.tumblr.com',
#  <NA>,
#  'https://nprmusic.tumblr.com',
#  'http://stories.kera.org',
#  'https://www.wbez.org',
#  'https://nprbooks.tumblr.com',
#  <NA>,
#  'http://www.texasstandard.org',
#  'https://www.surveymonkey.com',
#  <NA>,
#  <NA>,
#  'http://smalltowntexas.kut.org',
#  'https://www.cpr.org',
#  'https://www.usa.gov',
#  'https://beyondbattlefield.tumblr.com',
#  'https://thekojonnamdishow.org',
#  'http://apps.stlpublicradio.org',
#  'https://archive.storycorps.org',
#  'https://wamu.org',
#  'http://www.playgroundsforeveryone.com',
#  'https://nprstorybook.tumblr.com',
#  'http://breakingground.wamu.org',
#  'https://whyy.org',
#  'https://projects.vpr.org',
#  <NA>,
#  'https://li.st',
#  'http://earbud.fm',
#  <NA>,
#  'https://www.houstonpublicmedia.org',
#  'https://tinydeskcontest.npr.org',
#  'https://elections.npr.org',
#  'https://www.kqed.org',
#  'https://www.nhpr.org',
#  'http://elections.npr.org',
#  'https://nprontheroad.tumblr.com',
#  'https://www.wbez.org',
#  'https://www.wyomingpublicmedia.org',
#  'https://wbhm.org',
#  <NA>,
#  'http://elections.wvpublic.org',
#  'https://indianapublicmedia.org',
#  'https://radioopensource.org',
#  'https://www.heatofthemoment.org',
#  'https://www.wwno.org',
#  'http://www.kera.org',
#  'https://www.latinousa.org',
#  'https://www.thisamericanlife.org',
#  'https://www.research.net',
#  'https://developers.googleblog.com',
#  'https://interactive.wbez.org',
#  'https://www.mprnews.org',
#  'https://www.nytimes.com',
#  'https://archive.nytimes.com',
#  'https://archive.nytimes.com',
#  'https://archive.nytimes.com',
#  'https://www.nytimes.com',
#  'https://archive.nytimes.com',
#  'https://www.nytimes.com',
#  'https://www.nytimes.com',
#  'https://www.nytimes.com',
#  'https://archive.nytimes.com',
#  'https://www.nytimes.com',
#  'https://www.nytimes.com',
#  'https://www.nytimes.com',
#  'https://www.nytimes.com',
#  'https://www.nytimes.com',
#  'https://www.nytimes.com',
#  'https://www.nytimes.com',
#  'https://cn.nytimes.com',
#  'https://www.nytimes.com',
#  'https://www.nytimes.com',
#  'https://www.nytimes.com',
#  <NA>,
#  'https://www.nytimes.com',
#  'https://www.nytimes.com',
#  <NA>,
#  'https://archive.nytimes.com',
#  'https://www.nytimes.com',
#  'https://archive.nytimes.com',
#  'https://www.nytimes.com',
#  'https://www.nytimes.com',
#  'https://archive.nytimes.com',
#  'https://www.nytimes.com',
#  'https://www.nytimes.com',
#  'https://www.nytimes.com',
#  <NA>,
#  'https://www.nytimes.com',
#  'https://www.nytimes.com',
#  'https://archive.nytimes.com',
#  'https://archive.nytimes.com',
#  'https://www.nytimes.com',
#  'https://www.nytimes.com',
#  'https://archive.nytimes.com',
#  'https://archive.nytimes.com',
#  <NA>,
#  <NA>,
#  'https://bitly.com',
#  'https://cooking.nytimes.com',
#  'https://www.nytimes.com',
#  'https://nyt.yul1.qualtrics.com',
#  'https://www.messenger.com',
#  'https://www.nytco.com',
#  'https://time.com',
#  'https://www.ew.com',
#  'https://eu.usatoday.com',
#  'https://eu.usatoday.com',
#  'https://bitly.com',
#  'https://eu.usatoday.com',
#  'https://link.brightcove.com:443',
#  'https://eu.usatoday.com',
#  'https://foursquare.com',
#  <NA>,
#  'https://open.spotify.com',
#  <NA>,
#  'https://eu.usatoday.com',
#  'https://eu.usatoday.com',
#  'https://eu.courier-journal.com',
#  'https://eu.usatoday.com',
#  'https://eu.usatoday.com',
#  'https://eu.usatoday.com',
#  'https://eu.usatoday.com',
#  'https://usatq.wordpress.com',
#  'https://www.abc10.com',
#  'https://reviewed.usatoday.com',
#  'https://reviewed.usatoday.com',
#  'https://reviewed.usatoday.com',
#  'https://eu.freep.com',
#  'https://reviewed.usatoday.com',
#  'https://eu.usatoday.com',
#  'https://eu.usatoday.com',
#  'https://eu.usatodayhss.com',
#  'https://reviewed.usatoday.com',
#  'https://reviewed.usatoday.com',
#  'https://www.gannett-cdn.com',
#  'https://reviewed.usatoday.com',
#  'https://reviewed.usatoday.com',
#  <NA>,
#  'https://eu.usatoday.com',
#  'https://eu.shreveporttimes.com',
#  'https://reviewed.usatoday.com',
#  'https://reviewed.usatoday.com',
#  'https://sportsdata.usatoday.com',
#  'https://eu.azcentral.com',
#  'https://eu.usatoday.com',
#  'https://eu.usatoday.com',
#  'https://reviewed.usatoday.com',
#  'https://hoopshype.com',
#  'https://eu.cincinnati.com',
#  'https://boxingjunkie.usatoday.com',
#  'https://reviewed.usatoday.com',
#  'https://eu.usatoday.com',
#  'https://mmajunkie.usatoday.com',
#  'https://sportswire.usatoday.com',
#  'https://reviewed.usatoday.com',
#  'https://10best.usatoday.com',
#  'https://eu.democratandchronicle.com',
#  'https://sportsdata.usatoday.com',
#  'https://www.militarytimes.com',
#  'http://www.12news.com',
#  'https://steelerswire.usatoday.com',
#  'https://reviewed.usatoday.com',
#  'https://eu.usatoday.com',
#  'https://eu.desmoinesregister.com',
#  'https://freshiesmag.com',
#  'https://boxingjunkie.usatoday.com',
#  'https://eu.usatoday.com',
#  'https://broncoswire.usatoday.com',
#  'https://livestream.com',
#  'https://eu.citizen-times.com',
#  'https://reviewed.usatoday.com',
#  'https://reviewed.usatoday.com',
#  'https://eu.floridatoday.com',
#  'https://www.heraldscotland.com',
#  'https://eu.clarionledger.com',
#  'http://on.thec-l.com',
#  'https://eu.indystar.com',
#  'https://eu.usatoday.com',
#  'https://eu.jsonline.com',
#  'https://eu.delmarvanow.com',
#  'https://coldcasepodcasts.tumblr.com',
#  <NA>,
#  <NA>,
#  'http://on.fb.me',
#  'https://www.facebook.com',
#  'https://newschallenge.tumblr.com',
#  <NA>,
#  <NA>,
#  <NA>,
#  <NA>,
#  <NA>,
#  <NA>,
#  'https://twitter.com',
#  <NA>,
#  'http://wpo.st',
#  'https://www.themarshallproject.org',
#  'http://blogs.wsj.com',
#  <NA>,
#  'https://washingtonpost.pdx1.qualtrics.com',
#  <NA>,
#  <NA>,
#  <NA>,
#  'https://www.marieclaire.com',
#  'https://historicallyblack.tumblr.com',
#  'https://www.dowjones.com',
#  'http://online.barrons.com',
#  'http://s.wsj.net',
#  'https://www.marketwatch.com',
#  <NA>,
#  'https://www.wsj.com',
#  'https://www.marketwatch.com',
#  ...]

# %%
# Create a dictionary for the mapping of unique domains to final domains
domain_mapping = dict(zip(unique_domains, final_domains))

# Replace the unique domains with final domains in the URLs
df_filtered["top_level_domain"] = df_filtered["top_level_domain"].replace(domain_mapping, regex=True)

# %%
df_filtered
# Out:
#        filename                                            message  \
# 0           abc  Roberts took the unusual step of devoting the ...
# 1           abc                     Do you agree with the new law?
# 2           abc  Some pretty cool confetti will rain down on Ne...
# 4           abc  The pharmacy was held up by a man seeking pres...
# 6           abc  There were no immediate reports of damage or i...
# ...         ...                                                ...
# 534386      wsj  “It took massive amounts of work, incredible a...
# 534387      wsj  As he has many times, Donald J. Trump cast his...
# 534388      wsj  As the Trump Organization's finance chief, All...
# 534389      wsj  HealthCare.gov has been straining to handle th...
# 534390      wsj  The battle for the House of Representatives ca...
#
#                                                      link  \
# 0       http://abcnews.go.com/blogs/headlines/2011/12/...
# 1       http://abcnews.go.com/blogs/politics/2011/12/w...
# 2       http://abcnews.go.com/blogs/headlines/2011/12/...
# 4       http://abcnews.go.com/US/ny-pharmacy-shootout-...
# 6       http://abcnews.go.com/International/wireStory/...
# ...                                                   ...
# 534386                          http://on.wsj.com/2fyLhrR
# 534387                          http://on.wsj.com/2exxAsn
# 534388                          http://on.wsj.com/2faR36h
# 534389                          http://on.wsj.com/2exw5dL
# 534390                          http://on.wsj.com/2fVigLs
#
#               top_level_domain
# 0       https://abcnews.go.com
# 1       https://abcnews.go.com
# 2       https://abcnews.go.com
# 4       https://abcnews.go.com
# 6       https://abcnews.go.com
# ...                        ...
# 534386       http://on.wsj.com
# 534387       http://on.wsj.com
# 534388       http://on.wsj.com
# 534389       http://on.wsj.com
# 534390       http://on.wsj.com
#
# [512049 rows x 4 columns]

# %%
len(df_filtered)
# Out:
# 512049

# %%
df_filtered_top_level = df_filtered.dropna(subset=['top_level_domain'])

# %%
len(df_filtered_top_level)
# Out:
# 481451

# %%
df_filtered_top_level = df_filtered_top_level.copy()
df_filtered_top_level['top_level_domain'] = df_filtered_top_level['top_level_domain'].str.replace(r'https?://(www\.)?|www\.', '', regex=True)
df_filtered_top_level['top_level_domain'] = df_filtered_top_level['top_level_domain'].str.strip()

# %%
df_filtered_top_level.head()
# Out:
#   filename                                            message  \
# 0      abc  Roberts took the unusual step of devoting the ...
# 1      abc                     Do you agree with the new law?
# 2      abc  Some pretty cool confetti will rain down on Ne...
# 4      abc  The pharmacy was held up by a man seeking pres...
# 6      abc  There were no immediate reports of damage or i...
#
#                                                 link top_level_domain
# 0  http://abcnews.go.com/blogs/headlines/2011/12/...   abcnews.go.com
# 1  http://abcnews.go.com/blogs/politics/2011/12/w...   abcnews.go.com
# 2  http://abcnews.go.com/blogs/headlines/2011/12/...   abcnews.go.com
# 4  http://abcnews.go.com/US/ny-pharmacy-shootout-...   abcnews.go.com
# 6  http://abcnews.go.com/International/wireStory/...   abcnews.go.com

# %% [markdown]
# Removing old links, fake domains and non-parallel news based on news agencies (the link inside the post must link to a news of the same news agency)

# %%
# Dictionary mapping the news agency to the list of domains associated. This dictionary is handcrafted & checked based on the final domains obtained.
domain_dict = {
    'cnn': ['us.cnn.com', 'edition.cnn.com'],
    'nbc': ['cnbc.com', 'nascartalk.nbcsports.com', 'nbcolympics.com', 'nbcsandiego.com', 'nbclosangeles.com', 'nbcchicago.com', 'nbcnews.com', 'nbcdfw.com', 'nbcnewyork.com', 'nbcbayarea.com', 'nbcwashington.com', 'nbcmiami.com', 'nbcsportschicago.com', 'nbcsportsbayarea.com', 'nbcsports.com'],
    'huffington': ['projects.huffingtonpost.com', 'elections.huffingtonpost.com', 'testkitchen.huffingtonpost.com', 'huffingtonpost.co.uk'],
    'washington': ['washingtonpost.com'],
    'usatoday': ['eu.shreveporttimes.com', 'ftw.usatoday.com', 'eu.usatoday.com', 'mmajunkie.usatoday.com', 'eu.citizen-times.com', 'eu.usatodayhss.com', 'sportswire.usatoday.com', 'sportsdata.usatoday.com', 'broncoswire.usatoday.com', 'boxingjunkie.usatoday.com'],
    'fox': ['foxnews.com', 'radio.foxnews.com', 'nation.foxnews.comgeo-block', 'fox29.com', 'fox59.com', 'fox4kc.com', 'fox5ny.com', 'foxbusiness.com'],
    'foxandfriends': ['foxnews.com', 'radio.foxnews.com', 'nation.foxnews.comgeo-block', 'fox29.com', 'fox59.com', 'fox4kc.com', 'fox5ny.com', 'foxbusiness.com'],
    'nytimes': ['archive.nytimes.com', 'nytimes.com', 'cooking.nytimes.com'],
    'abc': ['abcnewsradioonline.com', 'abcnews.go.com', 'abc7ny.com', 'abc7.com', 'abc11.com', 'abc13.com', 'abc7chicago.com', 'abc7news.com'],
    'bbc': ['bbc.co.uk', 'bbc.com'],
    'wsj': ['financingthefuture.wsj.com', 'wsj.com', 'blogs.wsj.com', 'graphics.wsj.com', 's.wsj.net'],
    'npr': ['elections.npr.org', 'elections2012.npr.org', 'blog.apps.npr.org', 'npr.org', 'stateimpact.npr.org'],
    'cbs': ['cbssports.com', 'cbs.com', 'cbsnews.com'],
    'latimes': ['latimes.com', 'events.latimes.com', 'homicide.latimes.com'],
    'time': ['time.com']
}

# %%
# Creating a tuple list with the filename and associated domains
filter_conditions = []
for filename, domains in domain_dict.items():
    for domain in domains:
        filter_conditions.append((filename, domain))

# Create a DataFrame from the filter conditions
filter_conditions_df = pd.DataFrame(filter_conditions, columns=['filename', 'top_level_domain'])

# Perform a merge to filter the original DataFrame based on the conditions
df_filtered_top_level = df_filtered_top_level.merge(filter_conditions_df, on=['filename', 'top_level_domain'], how='inner')

# %%
len(df_filtered_top_level)
# Out:
# 275075

# %%
df_filtered_top_level.head()
# Out:
#   filename                                            message  \
# 0      abc  Roberts took the unusual step of devoting the ...
# 1      abc                     Do you agree with the new law?
# 2      abc  Some pretty cool confetti will rain down on Ne...
# 3      abc  The pharmacy was held up by a man seeking pres...
# 4      abc  There were no immediate reports of damage or i...
#
#                                                 link top_level_domain
# 0  http://abcnews.go.com/blogs/headlines/2011/12/...   abcnews.go.com
# 1  http://abcnews.go.com/blogs/politics/2011/12/w...   abcnews.go.com
# 2  http://abcnews.go.com/blogs/headlines/2011/12/...   abcnews.go.com
# 3  http://abcnews.go.com/US/ny-pharmacy-shootout-...   abcnews.go.com
# 4  http://abcnews.go.com/International/wireStory/...   abcnews.go.com

# %% [markdown]
# ### Make the dataset more manageable, reming some random rows
# In future work we could skip this part, but the computational cost must be considered!

# %%
# Group the DataFrame by the 'filename' column 
grouped = df_filtered_top_level.groupby('filename')

# Create an empty list to store the sampled dataframes
sampled_dfs = []

# For each unique filename, take a random sample of 2000 rows
for filename, group in grouped:
    # If there are more than 2000 rows for the filename, sample 2000, otherwise take all rows
    sampled = group.sample(n=min(2250, len(group)), random_state=42)
    sampled_dfs.append(sampled)

# Concatenate all the sampled dataframes
df_filtered_top_level_filtered = pd.concat(sampled_dfs)

# %%
df_filtered_top_level_filtered.head()
# Out:
#      filename                                            message  \
# 8644      abc  Marco Rubio repeated a similar line at least 4...
# 1076      abc  A California parole board will meet today to d...
# 2970      abc              The Force is strong with Angry Birds.
# 2029      abc                               $20K for Drumsticks?
# 8543      abc  A precious photo of a Florida deputy spending ...
#
#                                                    link top_level_domain
# 8644  http://abcnews.go.com/Politics/marco-rubio-rep...   abcnews.go.com
# 1076  http://abcnews.go.com/US/california-mass-murde...   abcnews.go.com
# 2970  http://abcnews.go.com/blogs/technology/2012/10...   abcnews.go.com
# 2029  http://abcnews.go.com/blogs/politics/2012/07/g...   abcnews.go.com
# 8543  http://abcnews.go.com/US/photo-shows-florida-d...   abcnews.go.com

# %%
len(df_filtered_top_level_filtered)
# Out:
# 27718

# %%
# Drop the unnecessary columns
df_filtered_top_level_filtered.drop(columns=['filename', 'top_level_domain'], inplace=True)

# %%
df_filtered_top_level_filtered.head()
# Out:
#                                                 message  \
# 8644  Marco Rubio repeated a similar line at least 4...
# 1076  A California parole board will meet today to d...
# 2970              The Force is strong with Angry Birds.
# 2029                               $20K for Drumsticks?
# 8543  A precious photo of a Florida deputy spending ...
#
#                                                    link
# 8644  http://abcnews.go.com/Politics/marco-rubio-rep...
# 1076  http://abcnews.go.com/US/california-mass-murde...
# 2970  http://abcnews.go.com/blogs/technology/2012/10...
# 2029  http://abcnews.go.com/blogs/politics/2012/07/g...
# 8543  http://abcnews.go.com/US/photo-shows-florida-d...

# %% [markdown]
# ### Scraping websites

# %%
# Updated headers with a recent User-Agent
HEADERS = {
    'User-Agent': ('Mozilla/5.0 (Windows NT 10.0; Win64; x64) '
                   'AppleWebKit/537.36 (KHTML, like Gecko) '
                   'Chrome/114.0.5735.110 Safari/537.36'),
    'Accept-Language': 'en-US,en;q=0.9',
    'Accept-Encoding': 'gzip, deflate, br',
}

# Function to scrape content from a URL using BeautifulSoup
def scrape_content(url):
    try:
        response = requests.get(url, headers=HEADERS, timeout=10)
        response.raise_for_status()
        print(f"Scraping {url}: status code {response.status_code}, content length {len(response.content)}")

        soup = BeautifulSoup(response.text, 'lxml')  # Use 'lxml' parser for better performance

        # Remove unwanted elements (scripts, styles, etc.)
        for element in soup.find_all(["script", "style", "header", "footer", "aside", "nav", "form", "figure"]):
            element.decompose()

        # Define possible content containers based on common website structures
        possible_containers = [
            'article',
            'div[id*="content"]',
            'div[class*="content"]',
            'div[id*="article"]',
            'div[class*="article"]',
            'div[id*="main"]',
            'div[class*="main"]',
            'section[class*="content"]',
            'section[class*="article"]',
            'main',
        ]

        article = None
        for container in possible_containers:
            article = soup.select_one(container)
            if article and article.find_all('p'):
                break

        # If no specific container is found, use the body tag as a fallback
        if not article:
            print(f"No specific content container found for {url}. Using the body tag as fallback.")
            article = soup.body

        # Extract text from the found article or body
        paragraphs = article.find_all('p')
        if not paragraphs:
            # If no paragraphs are found, extract all text
            text = article.get_text(separator=' ', strip=True)
        else:
            text = ' '.join([p.get_text(strip=True) for p in paragraphs])

        if text:
            return text.strip()
        else:
            print(f"No text extracted from {url}.")
            return None

    except requests.exceptions.HTTPError as http_err:
        if response.status_code == 404:
            print(f"404 Error: Page not found for {url}")
        else:
            print(f"HTTP error occurred: {http_err} for {url}")
    except requests.exceptions.Timeout:
        print(f"Timeout while scraping {url}")
    except requests.exceptions.RequestException as e:
        print(f"Error scraping {url}: {str(e)}")
    except Exception as e:
        print(f"Unexpected error scraping {url}: {str(e)}")
    return None

# Function to scrape content using Newspaper3k as a fallback
def scrape_content_with_newspaper(url):
    try:
        article = Article(url)
        article.download()
        article.parse()
        text = article.text.strip()
        if text:
            print(f"Successfully extracted content using Newspaper3k for {url}")
            return text
        else:
            print(f"No text extracted with Newspaper3k from {url}.")
            return None
    except Exception as e:
        print(f"Error scraping {url} with Newspaper3k: {str(e)}")
        return None

def load_progress(df, filename='progress.csv'):
    if os.path.exists(filename):
        print(f"Loading progress from {filename}")
        progress_df = pd.read_csv(filename, dtype={'link': str, 'original': str, 'status': str}, low_memory=False)
        # Filter progress_df to include only links present in df
        progress_df = progress_df[progress_df['link'].isin(df['link'])]
        return progress_df
    return None

def save_progress(df, filename='progress.csv'):
    # Save only the 'link', 'original', and 'status' columns
    df[['link', 'original', 'status']].to_csv(filename, index=False)
    print(f"Progress saved to {filename}")

# Function to validate URL before scraping
def is_url_valid(url):
    try:
        response = requests.head(url, headers=HEADERS, timeout=5)
        if response.status_code == 404:
            return False
        return True
    except requests.exceptions.RequestException:
        return False

# Main scraping function
def scrape_articles(input_data, checkpoint_interval=10, clear_output_interval=300):
    if isinstance(input_data, pd.DataFrame):
        df = input_data.copy()
        print("Using in-memory DataFrame as input.")
    else:
        df = pd.read_csv(input_data)
        print(f"Loaded data from file: {input_data}")

    # Ensure 'status' and 'original' columns exist
    if 'status' not in df.columns:
        df['status'] = ''
    if 'original' not in df.columns:
        df['original'] = ''

    # Ensure 'link' column is string and strip whitespaces
    df['link'] = df['link'].astype(str).str.strip()

    # Remove duplicates based on the 'link' column
    df = df.drop_duplicates(subset='link').reset_index(drop=True)
    print(f"Length of df after removing duplicates: {len(df)}")

    # Check for existing progress
    progress_df = load_progress(df)
    if progress_df is not None:
        # Ensure 'link' column in progress_df is string and strip whitespaces
        progress_df['link'] = progress_df['link'].astype(str).str.strip()

        # Remove duplicates in progress_df
        progress_df = progress_df.drop_duplicates(subset='link').reset_index(drop=True)

        # Merge progress with the original DataFrame
        df = df.merge(
            progress_df[['link', 'original', 'status']],
            on='link',
            how='left',
            suffixes=('', '_progress'),
            validate='one_to_one'
        )

        # Update 'original' and 'status' columns with progress
        for col in ['original', 'status']:
            progress_col = f"{col}_progress"
            if progress_col in df.columns:
                df[col] = df[progress_col]
                df.drop(columns=[progress_col], inplace=True)
        print("Resuming from previous progress.")

    # Fill NaN values in 'original' and 'status' with empty strings
    df['original'] = df['original'].fillna('')
    df['status'] = df['status'].fillna('')

    # Convert 'original' and 'status' columns to string
    df['original'] = df['original'].astype(str)
    df['status'] = df['status'].astype(str)

    total_rows = df.shape[0]
    print(f"Total rows to process: {total_rows}")

    # Iterate over DataFrame rows using enumerate
    for i, (index, row) in enumerate(df.iterrows()):
        # Skip if 'status' is not empty
        if row['status'] != '':
            continue

        url = row['link']

        # Validate URL before scraping
        if not is_url_valid(url):
            print(f"URL is invalid (404 Not Found): {url}")
            df.at[index, 'status'] = 'failed'
            continue  # Skip to the next URL

        content = scrape_content(url)
        if not content:
            print(f"No content found with BeautifulSoup for {url}. Trying Newspaper3k.")
            content = scrape_content_with_newspaper(url)
        if content:
            df.at[index, 'original'] = content
            df.at[index, 'status'] = 'success'
            print(f"Scraped content for index {index}, length: {len(content)}")
        else:
            print(f"Failed to scrape content for index {index}")
            df.at[index, 'status'] = 'failed'

        # Sleep to avoid overwhelming the server (randomized delay)
        time.sleep(random.uniform(0.5, 1.5))

        # Clear output every 'clear_output_interval' iterations
        if (i + 1) % clear_output_interval == 0:
            clear_output(wait=True)
            print(f"Output cleared after {i + 1} iterations.")

        # Save progress at intervals
        if (i + 1) % checkpoint_interval == 0:
            save_progress(df)

    # Final save after completing the loop
    save_progress(df)
    return df

# %%
# Copy the dataframe - 
scraped_df = df_filtered_top_level_filtered.copy(deep=True)
scraped_df=scraped_df.iloc[:, :2]
# Run the scraper
scraped_df = scrape_articles(scraped_df, checkpoint_interval=50,  clear_output_interval=300)
# Out:
# Progress saved to progress.csv
#
# HTTP error occurred: 401 Client Error: HTTP Forbidden for url: https://www.wsj.com/articles/amazon-launches-4k-streaming-video-for-prime-members-1418159683?mod=e2fb for http://www.wsj.com/articles/amazon-launches-4k-streaming-video-for-prime-members-1418159683?mod=e2fb
#
# No content found with BeautifulSoup for http://www.wsj.com/articles/amazon-launches-4k-streaming-video-for-prime-members-1418159683?mod=e2fb. Trying Newspaper3k.
#
# Error scraping http://www.wsj.com/articles/amazon-launches-4k-streaming-video-for-prime-members-1418159683?mod=e2fb with Newspaper3k: Article `download()` failed with 403 Client Error: Forbidden for url: https://www.wsj.com/articles/amazon-launches-4k-streaming-video-for-prime-members-1418159683?mod=e2fb on URL http://www.wsj.com/articles/amazon-launches-4k-streaming-video-for-prime-members-1418159683?mod=e2fb
#
# Failed to scrape content for index 27000
#
# HTTP error occurred: 401 Client Error: HTTP Forbidden for url: https://www.wsj.com/video/business-jet-makers-search-for-recovery-in-dubai/DA9352F5-AF9C-4A97-8F50-0C0E93DB9B35.html?mod=e2fb for http://www.wsj.com/video/business-jet-makers-search-for-recovery-in-dubai/DA9352F5-AF9C-4A97-8F50-0C0E93DB9B35.html?mod=e2fb
#
# No content found with BeautifulSoup for http://www.wsj.com/video/business-jet-makers-search-for-recovery-in-dubai/DA9352F5-AF9C-4A97-8F50-0C0E93DB9B35.html?mod=e2fb. Trying Newspaper3k.
#
# Error scraping http://www.wsj.com/video/business-jet-makers-search-for-recovery-in-dubai/DA9352F5-AF9C-4A97-8F50-0C0E93DB9B35.html?mod=e2fb with Newspaper3k: Article `download()` failed with 403 Client Error: Forbidden for url: https://www.wsj.com/video/business-jet-makers-search-for-recovery-in-dubai/DA9352F5-AF9C-4A97-8F50-0C0E93DB9B35.html?mod=e2fb on URL http://www.wsj.com/video/business-jet-makers-search-for-recovery-in-dubai/DA9352F5-AF9C-4A97-8F50-0C0E93DB9B35.html?mod=e2fb
#
# Failed to scrape content for index 27001
#
# HTTP error occurred: 401 Client Error: HTTP Forbidden for url: https://www.wsj.com/articles/some-muslim-migrants-find-more-than-refuge-in-europes-churches-1442437388?mod=e2fb for http://www.wsj.com/articles/some-muslim-migrants-find-more-than-refuge-in-europes-churches-1442437388?mod=e2fb
#
# No content found with BeautifulSoup for http://www.wsj.com/articles/some-muslim-migrants-find-more-than-refuge-in-europes-churches-1442437388?mod=e2fb. Trying Newspaper3k.
#
# Error scraping http://www.wsj.com/articles/some-muslim-migrants-find-more-than-refuge-in-europes-churches-1442437388?mod=e2fb with Newspaper3k: Article `download()` failed with 403 Client Error: Forbidden for url: https://www.wsj.com/articles/some-muslim-migrants-find-more-than-refuge-in-europes-churches-1442437388?mod=e2fb on URL http://www.wsj.com/articles/some-muslim-migrants-find-more-than-refuge-in-europes-churches-1442437388?mod=e2fb
#
# Failed to scrape content for index 27002
#
# HTTP error occurred: 401 Client Error: HTTP Forbidden for url: https://www.wsj.com/articles
mod=e2fb
#
# URL is invalid (404 Not Found): http://www.wsj.com/articles/yellen-reiterates-opposition-to-taylor-rule-in-letter-to-ryan-pelosi-1447778723?mod=e2fb
#
# URL is invalid (404 Not Found): http://www.wsj.com/articles/steve-kerrs-peculiar-playbook-1431456522?mod=e2fb
#
# URL is invalid (404 Not Found): http://www.wsj.com/articles/a-year-after-ferguson-black-lives-matter-still-yields-influence-1439143426
#
# URL is invalid (404 Not Found): http://blogs.wsj.com/indiarealtime/2015/12/09/why-delhi-doesnt-have-a-beijing-style-response-to-pollution/?mod=e2fb
#
# URL is invalid (404 Not Found): http://blogs.wsj.com/speakeasy/2016/01/28/equity-offers-a-rare-view-of-wall-street-from-a-womans-perspective/?mod=e2fb
#
# URL is invalid (404 Not Found): http://www.wsj.com/articles/china-curbs-elite-education-programs-1450665387?mod=e2fb
#
# URL is invalid (404 Not Found): http://www.wsj.com/articles/a-taste-of-italy-in-jaipur-india-1454515243?mod=e2fb
#
# URL is invalid (404 Not Found): http://blogs.wsj.com/indiarealtime/2015/07/06/greece-voted-no-how-the-indian-market-reacted/
#
# URL is invalid (404 Not Found): http://www.wsj.com/articles/poor-contact-lens-hygiene-puts-users-at-risk-of-serious-infections-1441648413?mod=e2fb
#
# URL is invalid (404 Not Found): http://www.wsj.com/articles/volkswagen-emissions-problem-exposed-by-routine-university-research-1443023854?mod=e2fb
#
# URL is invalid (404 Not Found): http://blogs.wsj.com/indiarealtime/2015/08/13/politics-gets-in-the-way-of-modis-india-overhaul/?mod=e2fb
#
# URL is invalid (404 Not Found): http://www.wsj.com/articles/female-startups-in-new-york-city-are-increasing-1456792282?mod=e2fb
#
# Progress saved to progress.csv

# %% [markdown]
# ### Removing a bad lines

# %%
#Copy the dataframe
scraped_df_new = scraped_df.copy(deep=True)
scraped_df_new.head()
# Out:
#                                              message  \
# 0  Marco Rubio repeated a similar line at least 4...
# 1  A California parole board will meet today to d...
# 2              The Force is strong with Angry Birds.
# 3                               $20K for Drumsticks?
# 4  A precious photo of a Florida deputy spending ...
#
#                                                 link   status  \
# 0  http://abcnews.go.com/Politics/marco-rubio-rep...  success
# 1  http://abcnews.go.com/US/california-mass-murde...  success
# 2  http://abcnews.go.com/blogs/technology/2012/10...  success
# 3  http://abcnews.go.com/blogs/politics/2012/07/g...  success
# 4  http://abcnews.go.com/US/photo-shows-florida-d...  success
#
#                                             original
# 0  Marco Rubio made his point again, and again, a...
# 1  The notorious "Helter Skelter" killer was deni...
# 2  Credit: Rovio Entertainment|LucasFilm Ltd. "An...
# 3  The General Services Administration is back in...
# 4  A photo shows a Florida deputy having a tea pa...

# %%
# Function to extract domain
def extract_domain(url):
    parsed_url = urlparse(url)
    domain = parsed_url.netloc
    # Remove leading 'www.' if present
    return domain.replace('www.', '')

# Apply the function to the 'link' column to create a new 'domain' column
scraped_df_new['domain'] = scraped_df_new['link'].apply(extract_domain)

# %%
len(scraped_df_new)
# Out:
# 27530

# %%
scraped_df_new.head()
# Out:
#                                              message  \
# 1  A California parole board will meet today to d...
# 2              The Force is strong with Angry Birds.
# 3                               $20K for Drumsticks?
# 4  A precious photo of a Florida deputy spending ...
# 5  “My advice to the Muslim Brotherhood is they n...
#
#                                                 link   status  \
# 1  http://abcnews.go.com/US/california-mass-murde...  success
# 2  http://abcnews.go.com/blogs/technology/2012/10...  success
# 3  http://abcnews.go.com/blogs/politics/2012/07/g...  success
# 4  http://abcnews.go.com/US/photo-shows-florida-d...  success
# 5  http://abcnews.go.com/blogs/politics/2013/07/e...  success
#
#                                             original          domain
# 1  The notorious "Helter Skelter" killer was deni...  abcnews.go.com
# 2  Credit: Rovio Entertainment|LucasFilm Ltd. "An...  abcnews.go.com
# 3  The General Services Administration is back in...  abcnews.go.com
# 4  A photo shows a Florida deputy having a tea pa...  abcnews.go.com
# 5  Egypt's ambassador to the U.S. says the Muslim...  abcnews.go.com

# %%
# Remove rows with 'status' as 'failed'
scraped_df_new = scraped_df_new[scraped_df_new['status'] != 'failed']

# %%
len(scraped_df_new)
# Out:
# 23552

# %%
#Remove rows with wrong scraped content
domains_to_remove = domain_dict['wsj'] + domain_dict['fox'] + domain_dict['foxandfriends']

# Filter out the rows where the domain is in the combined list
scraped_df_new = scraped_df_new[~scraped_df_new['domain'].isin(domains_to_remove)]

# %%
len(scraped_df_new)
# Out:
# 22943

# %%
# Remove rows with NA
scraped_df_new = scraped_df_new.dropna()

# %%
#Remove non unicode characters
def normalize_encoding(text):
    if isinstance(text, bytes):
        return text.decode('utf-8', errors='ignore')
    return text

scraped_df_new["message"] = scraped_df_new["message"].apply(normalize_encoding)
scraped_df_new["original"] = scraped_df_new["original"].apply(normalize_encoding)

# %%
# Function to trim and replace multiple spaces with one
def clean_string_columns(df):
    # Select only string columns and apply the transformation
    str_cols = df.select_dtypes(include=['object', 'string'])
    df[str_cols.columns] = str_cols.apply(lambda col: col.str.split().str.join(' '))
    return df

# Apply the function to the DataFrame
scraped_df_new = clean_string_columns(scraped_df_new)

# %%
# Replace empty strings with pd.NA
scraped_df_new.replace("", pd.NA, inplace=True)

# Remove rows with NA
scraped_df_new = scraped_df_new.dropna()

# %%
len(scraped_df_new)
# Out:
# 22943

# %% [markdown]
# ### Removing harmful content

# %%
#Remove unwanted columns
scraped_df_new.drop(columns=['link', 'status','domain'], inplace=True)

# %%
scraped_df_new.head()
# Out:
#                                              message  \
# 1  A California parole board will meet today to d...
# 2              The Force is strong with Angry Birds.
# 3                               $20K for Drumsticks?
# 4  A precious photo of a Florida deputy spending ...
# 5  “My advice to the Muslim Brotherhood is they n...
#
#                                             original
# 1  The notorious "Helter Skelter" killer was deni...
# 2  Credit: Rovio Entertainment|LucasFilm Ltd. "An...
# 3  The General Services Administration is back in...
# 4  A photo shows a Florida deputy having a tea pa...
# 5  Egypt's ambassador to the U.S. says the Muslim...

# %%
len(scraped_df_new)
# Out:
# 22943

# %%
# Function to remove rows where any string cell starts with "Don't want to wait?" (ignoring case)
def remove_rows_starting_with_phrase(df, phrase):
    # Define a helper function to check if a cell starts with the specified phrase
    def starts_with_phrase(cell):
        if isinstance(cell, str):
            return not cell.lower().startswith(phrase.lower())
        return True  # Non-string values are ignored

    # Apply the condition to the entire DataFrame
    return df[df.apply(lambda row: all(starts_with_phrase(cell) for cell in row), axis=1)]

# Apply the function
phrase = "Don't want to wait?"
scraped_df_new = remove_rows_starting_with_phrase(scraped_df_new, phrase)

# %%
len(scraped_df_new)
# Out:
# 22857

# %%
# Define the function to remove links at the end of a string
def remove_links_at_end(s):
    if isinstance(s, str):
        # Updated regex to match URLs at the end, ignoring spaces before and after the URL
        pattern = re.compile(r'\s*(https?://|www\.)\S+\s*$')
        prev_s = None
        while prev_s != s:
            prev_s = s
            s = pattern.sub('', s)
        return s.strip()  # Strip any leftover spaces after removing the URL
    else:
        return s

# Apply the function to all cells in the DataFrame
scraped_df_new = scraped_df_new.apply(lambda col: col.apply(remove_links_at_end))

# %%
# Regular expression patterns to match dates in common formats
date_patterns = [
    r'\b\d{1,2}[-/]\d{1,2}[-/]\d{2,4}\b',  # Matches dates like 25/09/2024 or 09-25-2024
    r'\b\d{4}[-/]\d{2}[-/]\d{2}\b',  # Matches dates like 2024-09-25
    r'\b\d{1,2} \w{3,9} \d{4}\b',  # Matches dates like 25 Sep 2024
    r'\b\w{3,9} \d{1,2}[,.]? \d{4}\b',  # Matches dates like September 25, 2024 or September 25. 2024
    r'\b\w{3} \d{1,2}[,.]? \d{4}\b',  # Matches dates like Mar 25, 2024 or Mar 25. 2024
    r'\b\d{1,2} \w{3,9}\b',  # Matches dates like 25 Sep
    r'\b\w{3,9} \d{1,2}\b'  # Matches dates like September 25
]

def remove_dates_from_string(text):
    # Remove dates from the beginning
    for pattern in date_patterns:
        text = re.sub(r'^' + pattern, '', text).strip()
        # Remove dates from the end
        text = re.sub(pattern + r'$', '', text).strip()
    return text

def clean_dataframe_dates(df):
    # Apply only to columns of type 'object' (usually strings)
    string_columns = df.select_dtypes(include=['object']).columns
    df[string_columns] = df[string_columns].apply(lambda col: col.apply(remove_dates_from_string))
    return df

# Clean the dataframe
scraped_df_new = clean_dataframe_dates(scraped_df_new)

# %%
# Function to remove the unwanted text from the end of each cell
def remove_phrase(cell):
    if isinstance(cell, str):
        return cell.replace('24/7 coverage of breaking news and live events', '', 1).strip()
    return cell

# Apply the function to all cells in the dataframe
scraped_df_new = scraped_df_new.apply(lambda col: col.apply(remove_phrase))

# %%
# Function to remove 'watch:' from the end of each string, ignoring case
def remove_watch_phrase(cell):
    if isinstance(cell, str):  # Apply only to strings
        # Use a regular expression to remove 'watch:' at the end of the string, ignoring case
        return re.sub(r'(?i)watch:$', '', cell).strip()
    return cell

# Apply the function to all cells in the dataframe
scraped_df_new = scraped_df_new.apply(lambda col: col.apply(remove_watch_phrase))

# %%
# Function to remove 'by X X' from the start of each string
def remove_by_name_phrase(cell):
    if isinstance(cell, str):
        return re.sub(r'(?i)^by \w+ \w+', '', cell).strip()
    return cell

# Apply the function to all cells in the dataframe
scraped_df_new = scraped_df_new.apply(lambda col: col.apply(remove_by_name_phrase))

# %%
# Function to trim and replace multiple spaces with one
def clean_string_columns(df):
    # Select only string columns and apply transformation to trim and replace multiple spaces with one
    string_columns = df.select_dtypes(include=['object', 'string'])
    df[string_columns.columns] = string_columns.apply(lambda x: x.str.split().str.join(' '))
    return df

# Apply the function to the DataFrame
scraped_df_new = clean_string_columns(scraped_df_new)

# Replace empty strings with pd.NA
scraped_df_new.replace("", pd.NA, inplace=True)

# Remove rows with NA
scraped_df_new = scraped_df_new.dropna()

# %%
def remove_rows_with_short_text(df):
    # Define a helper function to check if a cell contains at least 7 words
    def has_minimum_words(cell):
        if isinstance(cell, str):
            return len(cell.split()) >= 7
        return True  # Non-string values are ignored for this condition

    # Apply the condition to each row, using only string columns
    return df[df.apply(lambda row: all(has_minimum_words(cell) for cell in row), axis=1)]

# Apply the function
scraped_df_new = remove_rows_with_short_text(scraped_df_new)

# %%
len(scraped_df_new)
# Out:
# 20565

# %%
# Function to ensure that each string ends with a period (.)
def ensure_period_at_end(cell):
    if isinstance(cell, str):  # Apply only to strings
        # If the string ends with any punctuation, replace it with a period
        cell = re.sub(r'[!?.,;:]+$', '.', cell)
        # If the string doesn't end with a period, add one
        if not cell.endswith('.'):
            cell += '.'
    return cell

# Apply the function to each column of type 'object' (strings)
for col in scraped_df_new.select_dtypes(include='object').columns:
    scraped_df_new[col] = scraped_df_new[col].apply(ensure_period_at_end)

# %%
scraped_df_new.head()
# Out:
#                                              message  \
# 1  A California parole board will meet today to d...
# 2              The Force is strong with Angry Birds.
# 4  A precious photo of a Florida deputy spending ...
# 5  “My advice to the Muslim Brotherhood is they n...
# 6  There are more than 129,817 federally licensed...
#
#                                             original
# 1  The notorious "Helter Skelter" killer was deni...
# 2  Credit: Rovio Entertainment|LucasFilm Ltd. "An...
# 4  A photo shows a Florida deputy having a tea pa...
# 5  Egypt's ambassador to the U.S. says the Muslim...
# 6  (Getty Images) There are more than 129,817 fed...

# %% [markdown]
# ### Remove bad alignments

# %%
# Clean the DataFrame
scraped_df_new = scraped_df_new.dropna(subset=['original', 'message'])
scraped_df_new = scraped_df_new[scraped_df_new['original'].str.strip() != '']
scraped_df_new = scraped_df_new[scraped_df_new['message'].str.strip() != '']

# Reset the index to align with positional indices
scraped_df_new.reset_index(drop=True, inplace=True)

# Load the pre-trained model with device setting
model_name = 'sentence-transformers/paraphrase-mpnet-base-v2'
device = 'cuda' if torch.cuda.is_available() else 'cpu'
model = SentenceTransformer(model_name, device=device)

# Define the similarity threshold and batch size
similarity_threshold = 0.7  # Adjust this value as needed
batch_size = 4096  # Adjust batch size based on hardware capabilities

# Initialize lists to store indices of rows to keep and similarities
indices_to_keep = []
similarities = []

# Prepare the DataFrame for batching
n_rows = len(scraped_df_new)
batches = range(0, n_rows, batch_size)

# Process the rows in batches
for start_idx in tqdm(batches, desc="Processing batches"):
    end_idx = min(start_idx + batch_size, n_rows)
    batch_df = scraped_df_new.iloc[start_idx:end_idx]
    
    # Extract texts from the batch
    journalistic_texts = batch_df['original'].tolist()
    conversational_texts = batch_df['message'].tolist()
    
    # Compute embeddings for both sets of texts in the batch
    journalistic_embeddings = model.encode(journalistic_texts, convert_to_tensor=True)
    conversational_embeddings = model.encode(conversational_texts, convert_to_tensor=True)

    # Compute cosine similarity between each pair of texts in the batch
    cosine_scores = util.cos_sim(journalistic_embeddings, conversational_embeddings).diagonal()
    
    # Handle potential zero vectors by filtering out NaN values
    valid_mask = ~torch.isnan(cosine_scores)
    valid_indices = [start_idx + i for i, valid in enumerate(valid_mask) if valid]
    valid_scores = cosine_scores[valid_mask]
    
    # Apply similarity threshold
    threshold_mask = valid_scores >= similarity_threshold
    batch_indices_to_keep = [valid_indices[i] for i, keep in enumerate(threshold_mask) if keep]
    batch_similarities = valid_scores[threshold_mask].cpu().tolist()
    
    # Append results to the final lists
    indices_to_keep.extend(batch_indices_to_keep)
    similarities.extend(batch_similarities)

# Add the similarity column for the filtered rows
df_filtered = scraped_df_new.iloc[indices_to_keep].copy()
df_filtered['Similarity'] = similarities

# Reset the index of the filtered DataFrame
df_filtered.reset_index(drop=True, inplace=True)

# Print the results
print(f"Total rows before filtering: {n_rows}")
print(f"Total rows after filtering: {len(df_filtered)}")
# Out:
# /opt/conda/lib/python3.10/site-packages/sentence_transformers/cross_encoder/CrossEncoder.py:13: TqdmExperimentalWarning: Using `tqdm.autonotebook.tqdm` in notebook mode. Use `tqdm.tqdm` instead to force console mode (e.g. in jupyter console)
#   from tqdm.autonotebook import tqdm, trange
# modules.json:   0%|          | 0.00/229 [00:00<?, ?B/s]
# config_sentence_transformers.json:   0%|          | 0.00/122 [00:00<?, ?B/s]
# README.md:   0%|          | 0.00/3.73k [00:00<?, ?B/s]
# sentence_bert_config.json:   0%|          | 0.00/53.0 [00:00<?, ?B/s]
# config.json:   0%|          | 0.00/594 [00:00<?, ?B/s]
# model.safetensors:   0%|          | 0.00/438M [00:00<?, ?B/s]
# tokenizer_config.json:   0%|          | 0.00/1.19k [00:00<?, ?B/s]
# vocab.txt:   0%|          | 0.00/232k [00:00<?, ?B/s]
# tokenizer.json:   0%|          | 0.00/466k [00:00<?, ?B/s]
# special_tokens_map.json:   0%|          | 0.00/239 [00:00<?, ?B/s]
# /opt/conda/lib/python3.10/site-packages/transformers/tokenization_utils_base.py:1617: FutureWarning: `clean_up_tokenization_spaces` was not set. It will be set to `True` by default. This behavior will be deprecated in transformers v4.45, and will be then set to `False` by default. For more details check this issue: https://github.com/huggingface/transformers/issues/31884
#   warnings.warn(
# 1_Pooling/config.json:   0%|          | 0.00/190 [00:00<?, ?B/s]
# Processing batches:   0%|          | 0/6 [00:00<?, ?it/s]
# Batches:   0%|          | 0/128 [00:00<?, ?it/s]
# Batches:   0%|          | 0/128 [00:00<?, ?it/s]
# Processing batches:  17%|█▋        | 1/6 [02:07<10:37, 127.49s/it]
# Batches:   0%|          | 0/128 [00:00<?, ?it/s]
# Batches:   0%|          | 0/128 [00:00<?, ?it/s]
# Processing batches:  33%|███▎      | 2/6 [04:17<08:35, 128.87s/it]
# Batches:   0%|          | 0/128 [00:00<?, ?it/s]
# Batches:   0%|          | 0/128 [00:00<?, ?it/s]
# Processing batches:  50%|█████     | 3/6 [06:16<06:13, 124.61s/it]
# Batches:   0%|          | 0/128 [00:00<?, ?it/s]
# Batches:   0%|          | 0/128 [00:00<?, ?it/s]
# Processing batches:  67%|██████▋   | 4/6 [08:25<04:12, 126.39s/it]
# Batches:   0%|          | 0/128 [00:00<?, ?it/s]
# Batches:   0%|          | 0/128 [00:00<?, ?it/s]
# Processing batches:  83%|████████▎ | 5/6 [10:23<02:03, 123.14s/it]
# Batches:   0%|          | 0/3 [00:00<?, ?it/s]
# Batches:   0%|          | 0/3 [00:00<?, ?it/s]
# Processing batches: 100%|██████████| 6/6 [10:26<00:00, 104.39s/it]
# Total rows before filtering: 20565
# Total rows after filtering: 5352

# %%
# Replace empty strings with pd.NA
df_filtered.replace("", pd.NA, inplace=True)

# Remove rows with NA
df_filtered = df_filtered.dropna()

# %%
len(df_filtered)
# Out:
# 5352

# %% [markdown]
# ### Saving the dataset

# %%
# Rename the columns
df_filtered = df_filtered.rename(columns={'original': 'journalistic', 'message': 'conversational'})
df_filtered = df_filtered[['journalistic', 'conversational']]

# %%
df_filtered.head()
# Out:
#                                         journalistic  \
# 0  A photo shows a Florida deputy having a tea pa...
# 1  Egypt's ambassador to the U.S. says the Muslim...
# 2  (Getty Images) There are more than 129,817 fed...
# 3  Ferrera thanks Trump for his offensive tactics...
# 4  L'Osservatore Romano Vatican Pool/Getty Images...
#
#                                       conversational
# 0  A precious photo of a Florida deputy spending ...
# 1  “My advice to the Muslim Brotherhood is they n...
# 2  There are more than 129,817 federally licensed...
# 3       America Ferrera to Donald Trump: Thanks! --.
# 4  This time there's no need to mourn; because th...

# %%
len(df_filtered)
# Out:
# 5352

# %%
df_filtered.to_csv("../corpora/J2C_news_EN.csv", index=False)
